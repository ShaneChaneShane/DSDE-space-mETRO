# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False
if IN_COLAB:
    # !apt-get install openjdk-8-jdk-headless -qq > /dev/null
    # !wget -q https://archive.apache.org/dist/spark/spark-3.3.2/spark-3.3.2-bin-hadoop3.tgz
    # !tar xf spark-3.3.2-bin-hadoop3.tgz
    # !mv spark-3.3.2-bin-hadoop3 spark
    # !pip install -q findspark
    import os
    os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
    os.environ["SPARK_HOME"] = "/content/spark"

# %%
import pandas as pd

import findspark
findspark.init()
spark_url = 'local'
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql.functions import split, col
from pyspark.sql import functions as F

import matplotlib.pyplot as plt
import numpy as np

# %%
num_cores = 8
spark = SparkSession.builder\
        .master(spark_url)\
        .appName('Spark Data Prep')\
        .config('spark.ui.port', '4040')\
        .config("spark.sql.execution.pyspark.udf.faulthandler.enabled", "true") \
        .config("spark.driver.memory", "16g") \
        .config("spark.executor.memory", "16g") \
        .config("spark.default.parallelism", str(num_cores)) \
        .config("spark.sql.shuffle.partitions", str(num_cores)) \
        .getOrCreate()
sc = spark.sparkContext
path = 'bangkok_traffy.csv'

# %%
df = spark.read.option("multiline", "true") \
               .option("quote", "\"") \
               .option("escape", "\"") \
               .csv(path, header=True, inferSchema=True)

# %%
df.printSchema()
# Out:
# root
#  |-- ticket_id: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- organization: string (nullable = true)
#  |-- comment: string (nullable = true)
#  |-- photo: string (nullable = true)
#  |-- photo_after: string (nullable = true)
#  |-- coords: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- subdistrict: string (nullable = true)
#  |-- district: string (nullable = true)
#  |-- province: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- state: string (nullable = true)
#  |-- star: integer (nullable = true)
#  |-- count_reopen: integer (nullable = true)
#  |-- last_activity: timestamp (nullable = true)

# %%
df.count()
# Out:
# 787026

# %%
df.select('type','organization','coords','province','state','timestamp','last_activity').show(10, truncate=False)
# Out:
# +-------------------+------------------------------------------------------------+------------------+-------------+---------+--------------------------+--------------------------+
# |type               |organization                                                |coords            |province     |state    |timestamp                 |last_activity             |
# +-------------------+------------------------------------------------------------+------------------+-------------+---------+--------------------------+--------------------------+
# |{ความสะอาด}        |เขตบางซื่อ                                                  |100.53084,13.81865|กรุงเทพมหานคร|เสร็จสิ้น|2021-09-03 19:51:09.453003|2022-06-04 22:34:14.609206|
# |{น้ำท่วม,ร้องเรียน}|เขตประเวศ,ฝ่ายโยธา เขตประเวศ                                |100.66709,13.67891|กรุงเทพมหานคร|เสร็จสิ้น|2021-09-19 21:56:08.924992|2022-06-21 15:21:09.532782|
# |{สะพาน}            |เขตสาทร                                                     |100.52649,13.72060|กรุงเทพมหานคร|เสร็จสิ้น|2021-09-26 12:03:52.594898|2022-06-06 08:17:12.272904|
# |{น้ำท่วม}          |เขตบางซื่อ,ฝ่ายโยธา เขตบางซื่อ                              |100.53099,13.81853|กรุงเทพมหานคร|เสร็จสิ้น|2021-10-14 17:45:27.713884|2022-09-08 15:35:43.784519|
# |{น้ำท่วม,ถนน}      |เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว                            |100.59165,13.82280|กรุงเทพมหานคร|เสร็จสิ้น|2021-12-09 19:29:08.408763|2022-08-12 14:18:44.884945|
# |{}                 |เขตลาดพร้าว,การไฟฟ้านครหลวง เขตนวลจันทร์                    |100.59131,13.80910|กรุงเทพมหานคร|เสร็จสิ้น|2021-12-13 12:53:36.861064|2023-03-14 19:09:14.947437|
# |{}                 |เขตดุสิต                                                    |100.50848,13.77832|กรุงเทพมหานคร|เสร็จสิ้น|2021-12-17 15:46:02.610983|2023-05-17 13:11:32.463984|
# |{ความสะอาด}        |เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ,ฝ่ายรักษาความสะอาดฯ เขตประเวศ|100.64690,13.67083|กรุงเทพมหานคร|เสร็จสิ้น|2021-12-18 21:50:52.437512|2024-11-26 11:17:39.760344|
# |{}                 |เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ                              |100.65617,13.72812|กรุงเทพมหานคร|เสร็จสิ้น|2021-12-22 06:03:58.450912|2022-06-24 13:32:34.671236|
# |{ท่อระบายน้ำ}      |เขตประเวศ,ฝ่ายโยธา เขตประเวศ                                |100.65440,13.68158|กรุงเทพมหานคร|เสร็จสิ้น|2021-12-22 17:15:33.294829|2022-06-20 20:12:04.99444 |
# +-------------------+------------------------------------------------------------+------------------+-------------+---------+--------------------------+--------------------------+
# only showing top 10 rows

# %%
print("Explore unique state:")
uniqueState = df.select('state').distinct().rdd.flatMap(lambda x: x).collect()
uniqueState
# Out:
# Explore unique state:
# ['กำลังดำเนินการ', 'รอรับเรื่อง', 'เสร็จสิ้น']

# %%
print("see the number of completed ticket")
print(df.filter((col('state') == "เสร็จสิ้น")).count())
# Out:
# see the number of completed ticket
# 645700

# %%
print("show all province")
dfprovince = df.groupBy("province").count().orderBy("count", ascending=False)
dfprovince.show(dfprovince.count(), truncate=False)
# Out:
# show all province
# +-----------------------------+------+
# |province                     |count |
# +-----------------------------+------+
# |กรุงเทพมหานคร                |660434|
# |จังหวัดกรุงเทพมหานคร         |125189|
# |จังหวัดLac                   |293   |
# |NULL                         |195   |
# |นนทบุรี                      |194   |
# |สมุทรปราการ                  |191   |
# |ปทุมธานี                     |81    |
# |จังหวัดนนทบุรี               |67    |
# |จังหวัดสมุทรปราการ           |53    |
# |จังหวัดจังหวัด กรุงเทพมหานคร |30    |
# |จังหวัดปทุมธานี              |29    |
# |สมุทรสาคร                    |26    |
# |นครราชสีมา                   |21    |
# |จังหวัดสมุทรสาคร             |19    |
# |นครปฐม                       |19    |
# |จังหวัดBorno                 |17    |
# |ภูเก็ต                       |14    |
# |จังหวัดนครปฐม                |11    |
# |จังหวัดเพชรบุรี              |10    |
# |จังหวัดราชบุรี               |9     |
# |ชลบุรี                       |8     |
# |จังหวัดBangkok               |6     |
# |จังหวัดSahel                 |5     |
# |จังหวัดTillabéri             |4     |
# |เชียงใหม่                    |4     |
# |พังงา                        |4     |
# |จังหวัดฉะเชิงเทรา            |4     |
# |ฉะเชิงเทรา                   |3     |
# |อุดรธานี                     |3     |
# |สระบุรี                      |3     |
# |ราชบุรี                      |3     |
# |ลำปาง                        |3     |
# |จังหวัดลพบุรี                |3     |
# |ขอนแก่น                      |3     |
# |เพชรบุรี                     |3     |
# |จังหวัดชลบุรี                |2     |
# |ตราด                         |2     |
# |จังหวัดนครศรีธรรมราช         |2     |
# |จังหวัดกรุงเทพฯ              |2     |
# |จังหวัดกระบี่                |2     |
# |จังหวัดพระนครศรีอยุธยา       |2     |
# |ลพบุรี                       |2     |
# |พระนครศรีอยุธยา              |2     |
# |แพร่                         |2     |
# |จันทบุรี                     |2     |
# |ยโสธร                        |2     |
# |พิษณุโลก                     |2     |
# |จังหวัดสระบุรี               |2     |
# |ระยอง                        |2     |
# |จังหวัดสงขลา                 |2     |
# |สุราษฎร์ธานี                 |2     |
# |จังหวัดเชียงใหม่             |2     |
# |ชุมพร                        |2     |
# |จังหวัดชุมพร                 |1     |
# |กาญจนบุรี                    |1     |
# |บุรีรัมย์                    |1     |
# |อุตรดิตถ์                    |1     |
# |เลย                          |1     |
# |แม่ฮ่องสอน                   |1     |
# |ศรีสะเกษ                     |1     |
# |เชียงราย                     |1     |
# |ลำพูน                        |1     |
# |สงขลา                        |1     |
# |จังหวัดPerak                 |1     |
# |จังหวัดจังหวัด               |1     |
# |มหาสารคาม                    |1     |
# |จังหวัดจ.ฉะเชิงเทรา          |1     |
# |จังหวัดจ.สุพรรณบุรี          |1     |
# |ประจวบคีรีขันธ์              |1     |
# |จังหวัดอำนาจเจริญ            |1     |
# |หนองคาย                      |1     |
# |สุรินทร์                     |1     |
# |จังหวัดจังหวัดพระนครศรีอยุธยา|1     |
# |ระนอง                        |1     |
# |จังหวัดประจวบคีรีขันธ์       |1     |
# |จังหวัดSteiermark            |1     |
# |สุพรรณบุรี                   |1     |
# |จังหวัดRiau                  |1     |
# |จังหวัดจังหวัดกรุงเทพมหานคร  |1     |
# |จังหวัดนครสวรรค์             |1     |
# |นครสวรรค์                    |1     |
# |จังหวัดจังหวัดพะเยา          |1     |
# +-----------------------------+------+

# %%
print("กรุงเทพ และปริมณฑล data count: ")
pattern = "(?i)กรุงเทพ|Bangkok|นนทบุรี|นครปฐม|ปทุมธานี|สมุทรปราการ|สมุทรสาคร"
df.filter(col("province").isNotNull() & col("province").rlike(pattern)).groupBy("province").count().orderBy("count", ascending=False).show(truncate=False)
# Out:
# กรุงเทพ และปริมณฑล data count:
# +----------------------------+------+
# |province                    |count |
# +----------------------------+------+
# |กรุงเทพมหานคร               |660434|
# |จังหวัดกรุงเทพมหานคร        |125189|
# |นนทบุรี                     |194   |
# |สมุทรปราการ                 |191   |
# |ปทุมธานี                    |81    |
# |จังหวัดนนทบุรี              |67    |
# |จังหวัดสมุทรปราการ          |53    |
# |จังหวัดจังหวัด กรุงเทพมหานคร|30    |
# |จังหวัดปทุมธานี             |29    |
# |สมุทรสาคร                   |26    |
# |จังหวัดสมุทรสาคร            |19    |
# |นครปฐม                      |19    |
# |จังหวัดนครปฐม               |11    |
# |จังหวัดBangkok              |6     |
# |จังหวัดกรุงเทพฯ             |2     |
# |จังหวัดจังหวัดกรุงเทพมหานคร |1     |
# +----------------------------+------+

# %%
print("See if all coords follow this pattern of ...,...")
coords_pattern = r"^-?\d+\.\d+,-?\d+\.\d+$"

# Filter rows where 'coords' do not match the pattern
invalid_coords = df.filter(~col('coords').rlike(coords_pattern))

# Show the rows with invalid coordinates
print("number of invalid coords format:")
invalid_coords.count()
# Out:
# See if all coords follow this pattern of ...,...
# number of invalid coords format:
# 0

# %% [markdown]
# # Data preprocessing

# %%
df = df.dropDuplicates()

# %%
df = df.dropna(subset=['ticket_id', 'organization','timestamp','last_activity','state','coords', 'type'], how='any')

# %% [markdown]
# ## preprocessing state and completion time calculation

# %%
df = df.filter(col('state')=="เสร็จสิ้น")

# %%
df = df.withColumn('completion_time_hours', 
                   (F.unix_timestamp('last_activity') - F.unix_timestamp('timestamp')) / 3600)

# %% [markdown]
# ## preprocessing coordinations

# %%
# Split the 'coords' column into two new columns 'latitude' and 'longitude'
df = df.withColumn('longitude', split(df['coords'], ',').getItem(0).cast('double')) \
       .withColumn('latitude', split(df['coords'], ',').getItem(1).cast('double'))

# %%
print("show some longitude and latitude values:")
df.select(df.longitude, df.latitude).show(5, truncate=False)

df.select(F.min('latitude'), F.max('latitude')).show()
df.select(F.min('longitude'), F.max('longitude')).show()

df.filter('longitude == 1000').show()
# Out:
# show some longitude and latitude values:
# +---------+--------+
# |longitude|latitude|
# +---------+--------+
# |100.68837|13.71887|
# |100.39562|13.74479|
# |100.53882|13.7188 |
# |100.51813|13.81481|
# |100.49231|13.68747|
# +---------+--------+
# only showing top 5 rows
# +-------------+-------------+
# |min(latitude)|max(latitude)|
# +-------------+-------------+
# |          0.0|      18.7929|
# +-------------+-------------+
#
# +--------------+--------------+
# |min(longitude)|max(longitude)|
# +--------------+--------------+
# |           0.0|     104.49722|
# +--------------+--------------+
#
# +---------+----+------------+-------+-----+-----------+------+-------+-----------+--------+--------+---------+-----+----+------------+-------------+---------------------+---------+--------+
# |ticket_id|type|organization|comment|photo|photo_after|coords|address|subdistrict|district|province|timestamp|state|star|count_reopen|last_activity|completion_time_hours|longitude|latitude|
# +---------+----+------------+-------+-----+-----------+------+-------+-----------+--------+--------+---------+-----+----+------------+-------------+---------------------+---------+--------+
# +---------+----+------------+-------+-----+-----------+------+-------+-----------+--------+--------+---------+-----+----+------------+-------------+---------------------+---------+--------+

# %% [markdown]
# ## deal with out of range coordination (outlier)

# %%
# Define the latitude and longitude bounds mainly in กรุงเทพ
latitude_min = 13.4
latitude_max = 14.3
longitude_min = 99.8
longitude_max = 101

# keep only the rows within the defined bounds
df = df.filter(
    (df['latitude'] >= latitude_min) & (df['latitude'] <= latitude_max) &
    (df['longitude'] >= longitude_min) & (df['longitude'] <= longitude_max))

# %% [markdown]
# ## preprocessing province

# %%
# keep only rows that province are กรุงเทพ และ ปริมณฑล
pattern = "(?i)กรุงเทพ|Bangkok|นนทบุรี|นครปฐม|ปทุมธานี|สมุทรปราการ|สมุทรสาคร"
df = df.filter(col("province").isNotNull() & col("province").rlike(pattern))

# %%
# Apply pattern matching and replace values
df = df.withColumn(
    "province",
    F.when(
        F.col("province").rlike("(?i).*กรุงเทพ.*|.*Bangkok.*"), "กรุงเทพมหานคร"
    )
    .when(F.col("province").rlike("(?i).*นนทบุรี.*"), "นนทบุรี")
    .when(F.col("province").rlike("(?i).*สมุทรปราการ.*"), "สมุทรปราการ")
    .when(F.col("province").rlike("(?i).*ปทุมธานี.*"), "ปทุมธานี")
    .when(F.col("province").rlike("(?i).*สมุทรสาคร.*"), "สมุทรสาคร")
    .when(F.col("province").rlike("(?i).*นครปฐม.*"), "นครปฐม")
    .otherwise(F.col("province"))
)

# %%
print("After province preprocessing:")
# Group by the cleaned-up province and count
df.groupBy("province").count().orderBy("count", ascending=False).show(df.count(), truncate=False)
# Out:
# After province preprocessing:
# +-------------+------+
# |province     |count |
# +-------------+------+
# |กรุงเทพมหานคร|638122|
# |สมุทรปราการ  |82    |
# |นนทบุรี      |64    |
# |ปทุมธานี     |34    |
# |สมุทรสาคร    |22    |
# |นครปฐม       |9     |
# +-------------+------+

# %% [markdown]
# ## preprocessing type

# %%
# remove rows with empty type
df = df.filter(df['type'] != '{}')
# Remove '{' and '}' and split the 'type' column by ','
df = df.withColumn('type_array', F.split(F.regexp_replace(df['type'], '[\{\}]', ''), ','))
# type_array is for visualization

# %%
# 1) explode array to one row per organization
type_counts = (
    df
    .withColumn("type_single", F.explode("type_array"))
    # optional: drop blanks / nulls
    .filter(F.col("type_single").isNotNull() & (F.col("type_single") != ""))
    # 2) group and count
    .groupBy("type_single")
    .count()
    # 3) sort by count (most first)
    .orderBy(F.desc("count"))
)

type_counts.show(20, truncate=False)
# Out:
# +-----------+------+
# |type_single|count |
# +-----------+------+
# |ถนน        |207794|
# |ทางเท้า    |87346 |
# |ความสะอาด  |62618 |
# |ความปลอดภัย|59600 |
# |กีดขวาง    |56342 |
# |แสงสว่าง   |54734 |
# |ร้องเรียน  |40247 |
# |น้ำท่วม    |37207 |
# |ท่อระบายน้ำ|36227 |
# |จราจร      |34398 |
# |ป้าย       |30634 |
# |เสียงรบกวน |30526 |
# |ต้นไม้     |26806 |
# |สะพาน      |24658 |
# |คลอง       |22023 |
# |สัตว์จรจัด |14732 |
# |สายไฟ      |13289 |
# |PM2.5      |6436  |
# |คนจรจัด    |6383  |
# |สอบถาม     |5379  |
# +-----------+------+
# only showing top 20 rows

# %%
# onehot for types

df_type = df.withColumn("type", F.explode("type_array"))

# replace commas, spaces, symbols with _ to avoid INVALID_ATTRIBUTE_NAME_SYNTAX column name error
df_type = df_type.withColumn(
    "type_clean",
    F.regexp_replace(
        "type",
        r"[^0-9A-Za-zก-๙_]",   # allow digits, A-Z, a-z, Thai, underscore
        "_"
    )
)

# add prefix BEFORE pivot
df_type = df_type.withColumn(
    "type_pivot_key",
    F.concat(F.lit("type_"), F.col("type_clean"))
)

# pivot type to columns
type_wide = (
    df_type
    .select("ticket_id", "type_pivot_key")
    .withColumn("value", F.lit(1.0))
    .groupBy("ticket_id")
    .pivot("type_pivot_key")
    .agg(F.first("value"))
)
# list of type columns
type_cols = [c for c in type_wide.columns if c != "ticket_id"]

# for type that the ticket is not, fill with 0
type_wide = type_wide.fillna(0.0, subset=type_cols)

# %% [markdown]
# ## preprocessing organization

# %%
# 'organization' to array
df = df.withColumn('organization_array', split(F.regexp_replace(F.col('organization'), '\\s*,\\s*', ','), ','))

# %%
# remove organization from the array that look like person names in parentheses, e.g. "... (นาง...)"/"... (นาย...)"
person_pattern = r'\( *?(นาย|นาง|น\.ส\.|นางสาว|ดร|ผอ)[^\)]*\)'
district_pattern = r'^\s*เขต.*$' 
# trim items, remove empties and remove items matching the person pattern
df = df.withColumn(
    "organization_array",
    F.filter(
        F.transform(F.col("organization_array"), lambda x: F.trim(x)),
        lambda x: (x != "") & (~F.lower(x).rlike(person_pattern) & (~F.lower(x).rlike(district_pattern)))
    )
)

# %%
print("Explore unique organizations:")
# explode the array column so each organization is a separate row, trim and filter empties, then collect distinct values
unique_orgs = (
	df.select(F.explode('organization_array').alias('org'))
	  .filter(F.col('org').isNotNull())
	  .select(F.trim(F.col('org')).alias('org'))
	  .filter(F.col('org') != '')
	  .distinct()
	  .rdd
	  .map(lambda row: row['org'])
	  .collect()
)
unique_orgs
# Out:
# Explore unique organizations:
# ['สำนักงานตำรวจแห่งชาติ (Royal Thai Police)',
#  'เขตลาดกระบัง',
#  'สำนักงานก่อสร้างและบูรณะ สำนักการโยธา (สกบ.สนย.) กทม.',
#  'เขตพญาไท',
#  'ฝ่ายรักษาความสะอาดฯ เขตดินแดง',
#  'เขตห้วยขวาง',
#  'เขตคลองสาน',
#  'สำนักงานระบบขนส่ง สขส.สจส. กทม.',
#  'ฝ่ายโยธา เขตมีนบุรี',
#  'เขตดุสิต',
#  'กลุ่มงานบริหารทรัพย์สิน สขส.สจส. กทม.',
#  'เขตบึงกุ่ม',
#  'การไฟฟ้านครหลวง เขตยานนาวา',
#  'กองระบบคลอง สำนักการระบายน้ำ',
#  'ศูนย์ก่อสร้างและบูรณะถนน 1 ส่วนก่อสร้างและบูรณะ 2 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)',
#  'รองปลัดฯ นายณรงค์ เรืองศรี',
#  'ฝ่ายโยธา เขตบางกะปิ',
#  'โรงพยาบาลกลาง สำนักการแพทย์',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตสาทร',
#  'สำนักงานประปาสาขาสุขุมวิท สสส.',
#  'ฝ่ายเทศกิจ เขตบางคอแหลม',
#  'ฝ่ายโยธา เขตลาดพร้าว',
#  'MEA บางขุนเทียน ไฟฟ้าสาธารณะ',
#  'ฝ่ายรักษาความสะอาดฯ เขตคลองเตย',
#  'ฝ่ายปกครอง เขตป้อมปราบศัตรูพ่าย',
#  'ฝ่ายรักษาความสะอาดฯ เขตยานนาวา',
#  'ฝ่ายโยธา เขตบางนา',
#  'สำนักงานประปาสาขาพญาไท สสญ.',
#  'สน.เตาปูน',
#  'ฝ่ายพัฒนาชุมชนฯ เขตพญาไท',
#  'สน.หนองค้างพลู',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตลาดกระบัง',
#  'การไฟฟ้านครหลวง เขตบางบัวทอง',
#  'สน.บางพลัด',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตวัฒนา',
#  'กลุ่มงานระบายน้ำ ฝ่ายโยธา@ห้วยขวาง',
#  'ฝ่ายเทศกิจ เขตดินแดง',
#  'สน.แสมดำ',
#  'CAT TELECOM (Official)',
#  'กลุ่มงานเทคโนโลยีจราจร 2 กทจ.สจส. กทม.',
#  'ฝ่ายโยธา เขตคลองเตย',
#  'ฝ่ายรักษาความสะอาดฯ เขตคลองสามวา',
#  'ศูนย์ก่อสร้างและบูรณะถนน 2 ส่วนก่อสร้างและบูรณะ 2 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)',
#  'สน.บางซื่อ',
#  'สน.มักกะสัน',
#  'ฝกจ.1',
#  'การไฟฟ้านครหลวง',
#  'สน.มีนบุรี',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตพระนคร',
#  'สำนักงานสัตวแพทย์สาธารณสุข สำนักอนามัย กทม.',
#  'สน.บางเสาธง',
#  'สำนักพัฒนาสังคม กทม.',
#  'ฝ่ายรักษาความสะอาดฯ เขตลาดกระบัง',
#  'สน.ปากคลองสาน',
#  'ฝ่ายการศึกษา เขตคลองสามวา',
#  'สน.ร่มเกล้า',
#  'ศูนย์ถ่ายทำภาพยนตร์ กทม.',
#  'สน.พลับพลาไชย 2',
#  'สกสกรรสสญ',
#  'ฝ่ายโยธา เขตหนองแขม',
#  'สน.วัดพระยาไกร',
#  'TOT smartcity',
#  'ฝ่ายพัฒนาชุมชนฯ เขตประเวศ',
#  'โครงการ DB สายสีเหลือง ฝอบ. กฟน.',
#  'ศูนย์กำจัดมูลฝอยอ่อนนุช กกฝ. สสล.',
#  'สน.ลำผักชี',
#  'สำนักการคลัง กทม.',
#  'กระทรวงพัฒนาสังคมและความมั่นคงของมนุษย์',
#  'สน.นิมิตรใหม่',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางบอน',
#  'พนักงานกวาด เขตบางขุนเทียน',
#  'พนักงานกวาด เขตบึงกุ่ม',
#  'พนักงานกวาด เขตประเวศ',
#  'จังหวัดภูเก็ต',
#  'สน.ทางด่วน 2 งานศูนย์ควบคุมจราจร ด่วน 2 กก.2 บก.จร. (สน.ด่วน 2)',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตคันนายาว',
#  'ส.ส.อุ๋ม ธณิกานต์ เขตดุสิต',
#  'ส่วนซ่อมบำรุงระบบท่อและโยธา สสมบ.',
#  'PTT HO',
#  'ปภ. สมุทรปราการ',
#  'ABS',
#  'อบต.พันท้ายนรสิงห์ จ.สมุทรสาคร',
#  'มหาวิทยาลัยเกษตรศาสตร์',
#  'ฝ่ายรายได้ เขตบางกะปิ',
#  'ตำรวจท่องเที่ยว บก.ทท.1',
#  'ตำรวจท่องเที่ยว กก.1 บก.ทท.1',
#  'สำนักงานเขตบางขุนเทียน',
#  'ฝ่ายทะเบียน เขตทุ่งครุ',
#  'พนักงานกวาด เขตวังทองหลาง',
#  'ฝ่ายพัฒนาชุมชนฯ เขตดินแดง',
#  'สำนักงานประชาสัมพันธ์ กทม.',
#  'ฝ่ายพัฒนาชุมชนฯ เขตภาษีเจริญ',
#  'โครงการ DB สายสีส้ม สญ.3 ฝอบ. กฟน.',
#  'สำนักงานเลขานุการ สำนักสิ่งแวดล้อม',
#  'ฝ่ายการศึกษา เขตจตุจักร',
#  'ฝ่ายปกครอง เขตธนบุรี',
#  'สำนักงานจัดกรรมสิทธิ์ สำนักการโยธา (สจก.สนย.) กทม.',
#  'ฝกจ.2 (ฝ่ายก่อสร้างระบบจ่ายน้ำ2)',
#  'รองปลัดฯ นายชาตรี วัฒนเขจร',
#  'ฝ่ายทะเบียน เขตบางเขน',
#  'สำนักงานจัดการมูลฝอยและสิ่งปฏิกูล สำนักสิ่งแวดล้อม',
#  'กระทรวงวัฒนธรรม',
#  'ฝ่ายปลูกบำรุงรักษา สสณ. สสล.',
#  'โครงการถนนหลังสวนและถนนสารสิน',
#  'ฝ่ายการศึกษา เขตสวนหลวง',
#  'ฝ่ายทะเบียน เขตทวีวัฒนา',
#  'ฝ่ายทะเบียน เขตดุสิต',
#  'พรรคประชาชน ดอนเมือง',
#  'ก้าวไกลประเวศ-สะพานสูง (ส.ส.คุง)',
#  'การไฟฟ้านครหลวงเขตบางนา',
#  'ฝ่ายการศึกษา เขตหนองแขม',
#  'รองปลัดฯ นายสุขสันต์ กิตติศุภกร',
#  'สภ.บางกรวย',
#  'กลุ่มงานวิจัยและพัฒนา สจฝ. สสล.',
#  'กองปฏิบัติการดับเพลิงและกู้ภัย 3 สปภ.',
#  'สบมกรกสสญ',
#  'พรรคก้าวไกลกรุงเทพมหานคร เขต 31',
#  'ฝ่ายรายได้ เขตคลองเตย',
#  'สน.สุวินทวงศ์',
#  'กลุ่มงานสวนสาธารณะ เขตบางเขน',
#  'พนักงานกวาด เขตบางคอแหลม',
#  'ฝ่ายปกครอง เขตบางกอกน้อย',
#  'บริษัทเอกชน',
#  'โครงการ DB ประชาราษฎร์ สาย 1 ฝอบ. กฟน.',
#  'ฝ่ายทะเบียน เขตยานนาวา',
#  'ศูนย์กำจัดมูลฝอยหนองแขม กกฝ. สสล.',
#  'ฝ่ายทะเบียน เขตปทุมวัน',
#  'ฝ่ายพัฒนาชุมชนฯ เขตดอนเมือง',
#  'กองนโยบายและแผนงาน สำนักสิ่งแวดล้อม',
#  '1111 ศูนย์รับเรื่องราวร้องทุกข์ของรัฐบาล',
#  'ฝ่ายเทศกิจ เขตหนองจอก',
#  'กลุ่มงานพิธีการ สลป.',
#  'สำนักงานเลขานุการสภา กทม.',
#  'ฝ่ายปกครอง เขตดุสิต',
#  'กลุ่มงานวิชาการ สสณ. สสล.',
#  'สนข.(สำนักงานนโยบายและแผนการจราจร)',
#  'สำนักงานเคหะนครหลวง สาขาดินแดง 1',
#  'สำนักงานเคหะนครหลวง สาขาออเงิน',
#  'ขอให้มีสิ่งอำนวยความสะดวกสำหรับคนพิการและผู้สูงอายุ',
#  'ฝ่ายทะเบียน เขตวังทองหลาง',
#  'กกจ.2 ฝกจ.1',
#  'ฝ่ายเทศกิจ สำนักงานเขตสาทร กรุงเทพมหานคร (SoSafe)',
#  'โครงการ DB พระราม 3 ณ ระนอง ฝอบ. กฟน.',
#  'ฝ่ายปกครอง เขตวังทองหลาง',
#  '3BB',
#  'ฝ่ายทะเบียน เขตประเวศ',
#  'กกจ.4 ฝกจ.1',
#  'สำนักการระบายน้ำ กทม.',
#  'กองบัญชาการตำรวจนครบาล (บช.น.)',
#  'เขตบางนา',
#  'กองบังคับการตำรวจจราจร (บก.จร.)',
#  'การไฟฟ้านครหลวง เขตบางเขน',
#  'ฝ่ายโยธา เขตจตุจักร',
#  'เขตบางขุนเทียน',
#  'กองบังคับการตำรวจนครบาล 1 (บก.น.1)',
#  'ฝ่ายเทศกิจ เขตสะพานสูง',
#  'ฝ่ายโยธา เขตบางกอกน้อย',
#  'ฝ่ายโยธา เขตราชเทวี',
#  'ฝ่ายโยธา เขตจอมทอง',
#  'เขตป้อมปราบศัตรูพ่าย',
#  'ฝ่ายโยธา เขตป้อมปราบศัตรูพ่าย',
#  'ฝ่ายโยธา เขตบึงกุ่ม',
#  'เขตพระโขนง',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตพญาไท',
#  'ฝ่ายโยธา เขตธนบุรี',
#  'เขตบางกอกใหญ่',
#  'การไฟฟ้านครหลวง เขตวัดเลียบ',
#  'ฝ่ายปกครอง เขตบางกะปิ',
#  'ฝ่ายเทศกิจ เขตบางกอกน้อย',
#  'กองบังคับการตำรวจนครบาล 7 (บก.น.7)',
#  'กรุงเทพธนาคม',
#  'ฝ่ายรักษาความสะอาดฯ เขตธนบุรี',
#  'ฝ่ายโยธา เขตสัมพันธวงศ์',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตยานนาวา',
#  'กองบังคับการตำรวจนครบาล 2 (บก.น.2)',
#  'สน.บางชัน',
#  'ฝ่ายเทศกิจ เขตบางกะปิ',
#  'ฝ่ายรักษาความสะอาดฯ เขตประเวศ',
#  'ฝ่ายรักษาความสะอาดฯ เขตวัฒนา',
#  'ฝ่ายเทศกิจ เขตวังทองหลาง',
#  'ยังไม่มีหน่วยงานรับผิดชอบ',
#  'สน.พระโขนง',
#  'ฝ่ายโยธา เขตดุสิต',
#  'ฝ่ายพัฒนาชุมชนฯ เขตราชเทวี',
#  'ฝ่ายเทศกิจ เขตดอนเมือง',
#  'กระทรวงคมนาคม',
#  'กลุ่มงานควบคุมการก่อสร้าง 4 กองควบคุมการก่อสร้าง (กคส.สนย.)',
#  'โครงการรัชดาภิเษก-อโศก',
#  'ฝ่ายโยธา เขตหลักสี่',
#  'ฝ่ายเทศกิจ เขตมีนบุรี',
#  'ฝ่ายรักษาความสะอาดฯ เขตพระโขนง',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตดินแดง',
#  'สำนักจราจรกลางกรุงเทพมหานคร',
#  'พนักงานกวาด เขตสะพานสูง',
#  'สน.ลาดพร้าว',
#  'ฝ่ายสิ่งแวดล้อม แขวงจันทรเกษม จตุจักร',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตทวีวัฒนา',
#  'ฝ่ายโยธา เขตหนองจอก',
#  'ส่วนก่อสร้าง (สกส.กรร.สสล.)',
#  'สน.บางยี่เรือ',
#  'ฝ่ายปกครอง เขตประเวศ',
#  'ฝ่ายรักษาความสะอาดและสวนสาธารณะ สำนักงานเขตยานนาวา',
#  'ฝ่ายโยธา เขตภาษีเจริญ',
#  'การท่าเรือแห่งประเทศไทย',
#  'สปนกรรสสญ',
#  'ฝ่ายรักษาความสะอาดฯ เขตหลักสี่',
#  'สน.สามเสน',
#  'สน.หัวหมาก',
#  'ส่วนนันทนาการ สำนักงานนันทนาการและส่งเสริมการเรียนรู้ สวท.',
#  'ฝ่ายรักษาความสะอาดฯ เขตปทุมวัน',
#  'ฝ่ายโยธา เขตลาดกระบัง',
#  'ศูนย์ระบบจราจร กทจ.สจส. กทม.',
#  'ฝ่ายพัฒนาชุมชนฯ เขตทุ่งครุ',
#  'ฝ่ายโยธา เขตบางกอกใหญ่',
#  'กลุ่มงานพัฒนาระบบโครงข่าย สบน.สขส.สจส. กทม.',
#  'สำนักงานหลักประกันสุขภาพแห่งชาติ (สปสช.)',
#  'ฝ่ายพัฒนาชุมชนฯ เขตมีนบุรี',
#  'กองโครงสร้างพื้นฐานเทคโนโลยีดิจิทัล สดท.',
#  'กลุ่มงานควบคุมอาคาร ฝ่ายโยธา เขตภาษีเจริญ',
#  'สน.บุปผาราม',
#  'พนักงานกวาด เขตบางนา',
#  'พนักงานกวาด เขตบางพลัด',
#  'พนักงานกวาด เขตจตุจักร',
#  'ฝ่ายปกครอง เขตสวนหลวง',
#  'โครงการรถไฟฟ้าสายสีเขียวเหนือ (ถนนพหลโยธิน และถนนลาดพร้าว)',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางนา',
#  'สำนักงานเลขานุการ สำนักการระบายน้ำ',
#  'อาคารสำนักงานใหญ่ NT',
#  'ฝ่ายพัฒนาชุมชนฯ เขตสะพานสูง',
#  'ฝ่ายทะเบียน เขตพญาไท',
#  'ฝ่ายปกครอง เขตสะพานสูง',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตราษฎร์บูรณะ',
#  'ฝ่ายสิ่งแวดล้อม แขวงเสนานิคม จตุจักร',
#  'พนักงานกวาด เขตภาษีเจริญ',
#  'ส่วนการท่องเที่ยว สำนักงานวัฒนธรรมและการท่องเที่ยว สวท.',
#  'พนักงานกวาด เขตหนองแขม',
#  'เทศบาลนครเชียงราย จ.เชียงราย',
#  'กระทรวงมหาดไทย',
#  'พนักงานกวาด เขตสวนหลวง',
#  'MEA บางขุนเทียน แก้ไฟฟ้าขัดข้อง',
#  'สถาบันการแพทย์ฉุกเฉินแห่งชาติ',
#  'ฝ่ายการศึกษา เขตบึงกุ่ม',
#  'กลุ่มงานควบคุมอาคาร 1 ส่วนควบคุมอาคาร 1 สำนักงานควบคุมอาคาร (สคอ.สนย.)',
#  'สถานีดับเพลิงและกู้ภัยดาวคะนอง',
#  'ฝ่ายการคลัง สลป.',
#  'ฝ่ายปกครอง เขตลาดกระบัง',
#  'ฝ่ายพัฒนาชุมชนฯ เขตคลองสามวา',
#  'พนักงานกวาด เขตจอมทอง',
#  'ส่วนปฏิบัติการลดน้ำสูญเสีย (สปน.กรร.สสล.)',
#  'พนักงานกวาด เขตคลองเตย',
#  'สำนักโยธา',
#  'พนักงานกวาด เขตบางกอกใหญ่',
#  'ฝ่ายพัฒนาชุมชนฯ เขตหนองแขม',
#  'ฝ่ายทะเบียน เขตบางรัก',
#  'พนักงานกวาด เขตบางซื่อ',
#  'กระทรวงแรงงาน',
#  'กองปฏิบัติการดับเพลิงและกู้ภัย 4 สปภ.',
#  'พนักงานกวาด เขตปทุมวัน',
#  'กลุ่มงานโครงการ ฝ่ายโยธา เขตบางเขน',
#  'ประชาชนสายไหม',
#  'รองปลัดฯ นายเฉลิมพล โชตินุชิต',
#  'ฝ่ายรายได้ เขตบางกอกน้อย',
#  'Chula TUN-JAI สำนักงานจัดการทรัพย์สิน',
#  'โรงพยาบาลเจริญกรุงประชารักษ์ สำนักการแพทย์',
#  'ฝ่ายการศึกษา เขตบางนา',
#  'กลุ่มงานรักษาความสะอาด เขตบางเขน',
#  'สำนักงานเลขานุการปลัดกรุงเทพมหานคร (บัญชีทางการ)',
#  'โครงการ DB สายสีส้ม สญ.4 ฝอบ. กฟน.',
#  'สส. ปวิตรา จิตตกิจ กรุงเทพมหานคร เขต 32',
#  'ฝคป',
#  'สำนักงานกฎหมายและคดี กทม.',
#  'สำนักงาน กสทช. (สายสื่อสาร)',
#  'ฝ่ายทะเบียน เขตบางบอน',
#  'บริษัท แพลน บี มีเดีย จำกัด',
#  'สำนักสิ่งแวดล้อม',
#  'สำนักงานเขตบางพลัด',
#  'กรมชลประทาน',
#  'สำนักงานเขตสายไหม',
#  'กองกำกับการ 8 กองบังคับการตำรวจทางหลวง (กก.8 บก.ทล.)',
#  'ฝ่ายโยธาเขตบางพลัด',
#  'สำนักงานเขตราชเทวี',
#  'ศูนย์ควบคุมระบบป้องกันน้ำท่วม กทม.',
#  'สำนักงานเคหะนครหลวง สาขาหัวหมาก',
#  'ฝ่ายการคลัง เขตตลิ่งชัน',
#  'ฝ่ายการคลัง เขตพญาไท',
#  'ฝ่ายเทศกิจ สำนักงานเขตพระนคร กรุงเทพมหานคร (SoSafe)',
#  'สำนักงานเขตปทุมวัน',
#  'สำนักงานเขตบางกะปิ',
#  'บริษัท ทีโอที จำกัด (มหาชน)',
#  'ฝ่ายทะเบียน เขตบางกอกน้อย',
#  'สำนักสิ่งแวดล้อม กทม.',
#  'เขตสาทร',
#  'เขตปทุมวัน',
#  'เขตภาษีเจริญ',
#  'เขตดินแดง',
#  'เขตบางซื่อ',
#  'ฝ่ายโยธา เขตบางซื่อ',
#  'กองกำกับการ 1 (สายตรวจ) กองบังคับการตำรวจจราจร (กก.1 บก.จร.)',
#  'งานตรวจพิสูจน์มลภาวะ กก.5 บก.จร.',
#  'ฝ่ายโยธา เขตบางรัก',
#  'เขตคันนายาว',
#  'ฝ่ายเทศกิจ เขตบางรัก',
#  'เขตคลองสามวา',
#  'สน.พญาไท',
#  'ฝ่ายโยธา เขตสะพานสูง',
#  'ผอ.เขตบางกอกน้อย (ดร.วรชล)',
#  'กองแผนงานและประสานสาธารณูปโภค สำนักการโยธา (กผภ.สนย.) กทม.',
#  'สน.บางนา',
#  'ฝ่ายเทศกิจ เขตสวนหลวง',
#  'เขตบางพลัด',
#  'กองบังคับการตำรวจนครบาล 6 (บก.น.6)',
#  'กลุ่มงานวางแผนและออกแบบ 1 สวจ.สจส. กทม.',
#  'ฝ่ายรักษาความสะอาดฯ เขตจตุจักร',
#  'การไฟฟ้านครหลวงเขตยานนาวา',
#  'ฝ่ายรักษาความสะอาดฯ เขตราชเทวี',
#  'เขตสายไหม',
#  'ฝ่ายรักษาความสะอาดฯ เขตสายไหม',
#  'เขตทวีวัฒนา',
#  'ฝ่ายโยธา เขตดินแดง',
#  'ฝ่ายเทศกิจ เขตบางซื่อ',
#  'เขตดอนเมือง',
#  'ฝ่ายเทศกิจ เขตสัมพันธวงศ์',
#  'กองควบคุมการก่อสร้าง สำนักการโยธา (กคส.สนย.) กทม.',
#  'ฝ่ายโยธา เขตบางบอน',
#  'การไฟฟ้านครหลวง เขตสามเสน',
#  'การไฟฟ้านครหลวง เขตลาดกระบัง',
#  'กองบังคับการตำรวจนครบาล 4 (บก.น.4)',
#  'สน.บางกอกน้อย',
#  'ส่วนออกแบบระบบการจราจร สวจ.สจส. กทม.',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตมีนบุรี',
#  'ฝ่ายโยธา เขตคลองสาน',
#  'สน.ทุ่งสองห้อง',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตจอมทอง',
#  'สำนักอนามัย กทม.',
#  'สน.ท่าข้าม',
#  'ฝ่ายโยธา เขตตลิ่งชัน',
#  'สน.ทองหล่อ',
#  'สน.หนองจอก',
#  'สน.หลักสอง',
#  'ฝ่ายรักษาความสะอาดฯ เขตมีนบุรี',
#  'สน.สำเหร่',
#  'สน.สมเด็จเจ้าพระยา',
#  'ฝ่ายเทศกิจ เขตตลิ่งชัน',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางแค',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางกอกน้อย',
#  'สำนักงานประปาสาขาประชาชื่น สสช.',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางกอกน้อย',
#  'สน.บึงกุ่ม',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตจตุจักร',
#  'ส่วนก่อสร้างและบูรณะ 1 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)',
#  'สน.พระราชวัง',
#  'สซท.สสภ.',
#  'โครงการตามแนวรถไฟฟ้าสายสีน้ำเงิน',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางรัก',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตภาษีเจริญ',
#  'ฝ่ายรักษาความสะอาดฯ เขตภาษีเจริญ',
#  'สน.ศาลาแดง',
#  'สำนักงานออกแบบ สำนักการโยธา (สอบ.สนย.) กทม.',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตป้อมปราบศัตรูพ่าย',
#  'สำนักงานประปาสาขาพระโขนง สสพ.',
#  'ฝ่ายปกครอง เขตดอนเมือง',
#  'สน.สายไหม',
#  'กรมการขนส่งทางบก',
#  'ฝ่ายรักษาความสะอาดฯ เขตคลองสาน',
#  'โครงการพระราม 3 ช่วงสะพานพระราม 9 ถึงเลียบทางพิเศษเฉลิมมหานคร',
#  'สน.วังทองหลาง',
#  'กลุ่มงานออกแบบสวน สสณ. สสล.',
#  'กรมเจ้าท่า (Marine Department)',
#  'สำนักป้องกันและบรรเทาสาธารณภัย กทม.',
#  'กระทรวงพาณิชย์',
#  'รักษาที่ ฝ่ายโยธา เขตดุสิต',
#  'สถานีตำรวจนครบาลพลับพลาไชย2',
#  'ระบายน้ำ ฝ่ายโยธา เขตดุสิต',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตหนองแขม',
#  'กรรสสญ',
#  'สน.บางกอกใหญ่',
#  'โยธาธิการ',
#  'งานเทศกิจ ฝ่ายรักษาความสงบ เทศบาลเมืองลัดหลวง',
#  'โครงการถนนอังรีดูนังต์',
#  'ส่วนสวนสาธารณะ 1 สสณ. สสล.',
#  'กลุ่มงานอาคารสถานที่ สลป.',
#  'ชมรมสตรองx กรุงเทพมหานคร เฝ้าระวังทุจริต',
#  'สน.ดุสิต',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตวังทองหลาง',
#  'แขวงทางหลวงจังหวัดสมุทรปราการ',
#  'สำนักงานจัดการทรัพย์สิน จุฬาลงกรณ์มหาวิทยาลัย',
#  'อำเภอเมืองสมุทรปราการ',
#  'ส่วนห้องสมุดและการเรียนรู้ สำนักงานนันทนาการและส่งเสริมการเรียนรู้ สวท.',
#  'ฝ่ายพัฒนาชุมชนฯ เขตยานนาวา',
#  'พนักงานกวาด เขตลาดพร้าว',
#  'ฝ่ายปกครอง เขตคลองเตย',
#  'พนักงานกวาด เขตสาทร',
#  'โรงพยาบาลผู้สูงอายุบางขุนเทียน สำนักการแพทย์',
#  'พนักงานกวาด เขตดอนเมือง',
#  'ฝ่ายพัฒนาชุมชนฯ เขตตลิ่งชัน',
#  'ฝ่ายปกครอง เขตลาดพร้าว',
#  'กรมสรรพสามิต',
#  'ตำรวจภูธรจังหวัดนนทบุรี (ภ.จว.นนทบุรี)',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางกอกใหญ่',
#  'พนักงานกวาด เขตห้วยขวาง',
#  'กระทรวงอุตสาหกรรม',
#  'ฝ่ายเทศกิจ เขตราษฎร์บูรณะ',
#  'พนักงานกวาด เขตคันนายาว',
#  'สยามสแควร์ (Siamsquare)',
#  'ก้าวไกลสวนหลวง-ประเวศ(หนองบอน) สุภกรก้าวไกล',
#  'ฝ่ายพัฒนาชุมชนฯ เขตปทุมวัน',
#  'ฝ่ายทะเบียน เขตสวนหลวง',
#  'โครงการถนนอรุณอัมรินทร์-บรมราชชนนี-พรานนก',
#  'ฝ่ายรายได้ เขตสาทร',
#  'โรงพยาบาลบางนากรุงเทพมหานคร สำนักการแพทย์',
#  'พนักงานกวาด เขตสัมพันธวงศ์',
#  'กลุ่มงานอาคาร ฝ่ายโยธา เขตบางเขน',
#  'ฝ่ายทะเบียน เขตคลองเตย',
#  'ฝ่ายรายได้ เขตตลิ่งชัน',
#  'พนักงานกวาด เขตป้อมปราบศัตรูพ่าย',
#  'งาน DB รื้อย้ายหลบโครงการ Floodway',
#  'พมจ.กรุงเทพมหานคร',
#  'บริษัท ทรู อินเทอร์เน็ต คอร์ปอเรชั่น จำกัด',
#  'คณะกรรมการป้องกันและปราบปรามการทุจริตแห่งชาติ (ป.ป.ช. NACC)',
#  'ฝ่ายปกครอง เขตดินแดง',
#  'กลุ่มงานระบายน้ำ (ฝ่ายโยธา เขตบางรัก)',
#  'ศูนย์เรื่องราวร้องทุกข์ สลป. (บัญชีทางการ)',
#  'โครงการ DB เชื่อมวิภาวดี-พหลโยธิน ช่วง 2 ฝอบ. กฟน.',
#  'ฝ่ายการศึกษา เขตสะพานสูง',
#  'สถานีตำรวจทางหลวง 1 กองกำกับการ 8 (ส.ทล.1 กก.8 บก.ทล.)',
#  'สำนักงานเขตดินแดง',
#  'ฝ่ายรายได้ เขตบางซื่อ',
#  'ฝ่ายทะเบียน เขตลาดกระบัง',
#  'ฝ่ายพัฒนาชุมชนและสวัสดิการสังคม สำนักงานเขตบางนา กรุงเทพมหานคร (SoSafe)',
#  'กองการสังคีต สำนักวัฒนธรรม กีฬา และการท่องเที่ยว',
#  'กระทรวงทรัพยากรธรรมชาติและสิ่งแวดล้อม',
#  'การบำรุงรักษาศาลาที่พักผู้โดยสาร สขส.สจส. กทม.',
#  'สน.ภาษีเจริญ',
#  'เขตหนองแขม',
#  'เขตบางรัก',
#  'สำนักงาน กสทช. (ศูนย์รับแจ้งปัญหา 1200)',
#  'ฝ่ายโยธา เขตคลองสามวา',
#  'เขตบางกอกน้อย',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางซื่อ',
#  'กองโครงการสายอากาศเป็นสายใต้ดิน1 ฝ่ายบริหารโครงการ การไฟฟ้านครหลวง (กคต.1 ฝบค. กฟน.)',
#  'ศูนย์ก่อสร้างและบูรณะถนน 2 ส่วนก่อสร้างและบูรณะ 1 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)',
#  'ฝ่ายโยธา เขตสายไหม',
#  'กลุ่มงานเครื่องหมายจราจร 2 สวจ.สจส. กทม.',
#  'ฝ่ายเทศกิจ เขตพระนคร',
#  'ฝ่ายโยธา เขตทวีวัฒนา',
#  'ฝ่ายเทศกิจ เขตทวีวัฒนา',
#  'ฝ่ายเทศกิจ เขตบางแค',
#  'ฝ่ายรักษาความสะอาดฯ เขตทวีวัฒนา',
#  'เขตทุ่งครุ',
#  'สน.ทุ่งครุ',
#  'ฝ่ายเทศกิจ เขตสายไหม',
#  'ฝ่ายรักษาความสะอาดฯ เขตจอมทอง',
#  'การไฟฟ้านครหลวง เขตคลองเตย',
#  'สน.บางเขน',
#  'ศูนย์ก่อสร้างและบูรณะถนน 1 ส่วนก่อสร้างและบูรณะ 1 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางกะปิ',
#  'การไฟฟ้านครหลวง เขตนวลจันทร์',
#  'การทางพิเศษแห่งประเทศไทย',
#  'ฝ่ายเทศกิจ เขตดุสิต',
#  'ฝ่ายเทศกิจ เขตทุ่งครุ',
#  'กลุ่มงานควบคุมการก่อสร้าง 1 กองควบคุมการก่อสร้าง (กคส.สนย.)',
#  'สน.โชคชัย',
#  'ฝ่ายรักษาความสะอาดฯ เขตสะพานสูง',
#  'กลุ่มงานโครงการก่อสร้างและบูรณะ ฝ่ายโยธา@ห้วยขวาง',
#  'สน.ตลิ่งชัน',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตสัมพันธวงศ์',
#  'สน.เพชรเกษม',
#  'สน.คลองตัน',
#  'สำนักงานเลขานุการผู้ว่าราชการกรุงเทพมหานคร (บัญชีทางการ)',
#  'ฝ่ายรักษาความสะอาดฯ เขตสวนหลวง',
#  'สน.บุคคโล',
#  'สน.ยานนาวา',
#  'สน.ห้วยขวาง',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางซื่อ',
#  'ฝ่ายโยธา เขตราษฎร์บูรณะ',
#  'ฝ่ายการศึกษา เขตมีนบุรี',
#  'องค์กรสวัสดิภาพสัตว์ The Hope Thailand',
#  'กลุ่มงานวางแผนและออกแบบ 2 สวจ.สจส. กทม.',
#  'ฝ่ายเทศกิจ เขตบึงกุ่ม',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตทุ่งครุ',
#  'สน.บางโพงพาง',
#  'โรงพยาบาลสิรินธร สำนักการแพทย์',
#  'องค์การขนส่งมวลชนกรุงเทพ (ขสมก.)',
#  'สน.พหลโยธิน',
#  'Traffy @ ITS Lab2',
#  'สน.ท่าพระ',
#  'ฝ่ายรายได้ เขตพญาไท',
#  'กลุ่มงานตรวจสอบระบบสาธารณูปโภค กองแผนงานและประสานสาธารณูปโภค (กผภ.สนย.)',
#  'โครงการ DB สายสีชมพู ฝอบ. กฟน.',
#  'สน.ลาดกระบัง',
#  'ส่วนก่อสร้างและบูรณะ 2 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)',
#  'สน.ชนะสงคราม',
#  'สปสช.เขต 13',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตคลองสาน',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางพลัด',
#  'กลุ่มงานโครงการฯ ฝ่ายโยธา เขตภาษีเจริญ',
#  'กลุ่มประสานงานและติดตาม กทม.',
#  'กรุงเทพโปร่งใส',
#  'ส่วนสวนสาธารณะ 2 สสณ. สสล.',
#  'จังหวัดสมุทรปราการ',
#  'เทศบาลเมืองลัดหลวง จ.สมุทรปราการ',
#  'ส่วนระบบขนส่งทางราง สขส.สจส. กทม.',
#  'ฝ่ายทะเบียน เขตจตุจักร',
#  'แจ้ง bug Traffy Fondue',
#  'กองบริการการจำหน่าย การไฟฟ้านครหลวงเขตลาดกระบัง',
#  'ฝ่ายปกครอง เขตหลักสี่',
#  'สำนักงานเลขานุการ สำนักการโยธา (สก.สนย.) กทม.',
#  'เทศบาลตำบลด่านสำโรง จ.สมุทรปราการ',
#  'สำนักงานพัฒนาระบบบริการทางการแพทย์ สำนักการแพทย์',
#  'สน.บางคอแหลม',
#  'กลุ่มงานควบคุมอาคาร ฝ่ายโยธา@เขตห้วยขวาง',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตคลองสามวา',
#  'สำนักงานระบายน้ำ',
#  'สำนักงานเลขานุการ สก.สจส. กทม.',
#  'ส่วนบริการลูกค้า สสมบ.',
#  'การประปานครหลวง สาขาตากสิน',
#  'ส่วนซ่อมบำรุงระบบท่อและโยธา (สซท.กรร.สสล.)',
#  'MEA บางขุนเทียน หม้อแปลงฯ',
#  'กองบัญชาการตำรวจท่องเที่ยว (บช.ทท.)',
#  'กลุ่มงานระบบขนส่งทางบกและทางน้ำ สบน.สขส.สจส. กทม.',
#  'โครงการ DB สายสีส้ม สญ.2 ฝอบ. กฟน.',
#  'เทศบาลตำบลศาลากลาง จ.นนทบุรี',
#  'ฝ่ายพัฒนาชุมชนฯ เขตสายไหม',
#  'ส่วนก่อสร้าง สสมบ.',
#  'ฝ่ายปกครอง เขตสาทร',
#  'พนักงานกวาด เขตลาดกระบัง',
#  'สน.อุดมสุข',
#  'ฝ่ายพัฒนาชุมชนฯ เขตคลองสาน',
#  'กองกำกับการ 4 (ศูนย์ควบคุม บก.02) กองบังคับการตำรวจจราจร (กก.4 บก.จร.)',
#  'พนักงานกวาด เขตบางกะปิ',
#  'กลุ่มงานควบคุมอาคาร 2 ส่วนควบคุมอาคาร 1 สำนักงานควบคุมอาคาร (สคอ.สนย.)',
#  'เทศบาลเมืองบางกรวย จ.นนทบุรี',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางขุนเทียน',
#  'MEA',
#  'ฝ่ายรายได้ เขตจอมทอง',
#  'ฝ่ายปกครอง เขตมีนบุรี',
#  'ฝ่ายปกครอง เขตบางซื่อ',
#  'ฝ่ายทะเบียน เขตคลองสามวา',
#  'โครงการตามแนวรถไฟฟ้าสายสีชมพู (ติวานนท์ - แจ้งวัฒนะ)',
#  'ส่วนบริการจัดการมูลฝอย สจฝ. สสล.',
#  'พนักงานกวาด เขตหลักสี่',
#  'ฝ่ายพัฒนาชุมชนฯ เขตจตุจักร',
#  'ฝ่ายทะเบียน เขตป้อมปราบศัตรูพ่าย',
#  'ฝ่ายพัฒนาชุมชนฯ เขตจอมทอง',
#  'ฝ่ายทะเบียน เขตบางขุนเทียน',
#  'พนักงานกวาด เขตมีนบุรี',
#  'สำนักงานเขตสาทร ฝ่ายเทศกิจ',
#  'ฝ่ายรายได้ เขตภาษีเจริญ',
#  'สส.วีรภัทร คันธะ พรรคประชาชน พระประแดง',
#  'พรรคก้าวไกลเขต12 แขวงท่าแร้ง ออเงิน จรเข้บัว',
#  'โรงพยาบาลศิริราช',
#  'พรรคประชาชน ยานนาวา-บางคอแหลม',
#  'พนักงานกวาด เขตราชเทวี',
#  'สซท.กรร.สสสภ.',
#  'ส.ส.ธีรัจชัย พันธุมาศ (หนองจอก มีนบุรี ลาดกระบัง)',
#  'กองปฏิบัติการดับเพลิงและกู้ภัย 1 สปภ.',
#  'ฝ่ายทะเบียน เขตบางนา',
#  'ฝ่ายรายได้ เขตมีนบุรี',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางขุนเทียน',
#  'ฝ่ายทะเบียน เขตคันนายาว',
#  'ฝ่ายทะเบียน เขตมีนบุรี',
#  'ส.ส.เท่าพิภพ ลิ้มจิตรกร',
#  'ฝ่ายปกครอง เขตทุ่งครุ',
#  'สำนักงานผู้ตรวจการแผ่นดิน',
#  'สำนักงานเขตบางเขน',
#  'ศูนย์ช่วยเหลือนักท่องเที่ยว กทม.',
#  'สำนักงานทรัพย์สิน มก.',
#  'ฝ่ายทะเบียน เขตพระนคร',
#  'กองบังคับการตรวจคนเข้าเมือง 1 (กรุงเทพมหานคร)',
#  'กองบังคับการตำรวจทางหลวง (บก.ทล.)',
#  'ฝ่ายการศึกษา เขตวังทองหลาง',
#  'สำนักงานเขตวังทองหลาง',
#  'เทศบาลนครปากเกร็ด จ.นนทบุรี',
#  'ฝ่ายรายได้ เขตทุ่งครุ',
#  'ศูนย์ช่วยเหลือนักท่องเที่ยว ท่าอากาศยานดอนเมือง',
#  'รับแจ้งข้อเสนอแนะติชม Traffy Fondue',
#  'ฝ่ายปกครอง เขตราชเทวี',
#  'บริษัท ทรู คอร์ปอเรชั่น จำกัด (มหาชน)',
#  'โรงพยาบาลรัตนประชารักษ์ สำนักการแพทย์',
#  'กปท.ฝจส.',
#  'ฝ่ายทะเบียน เขตวัฒนา',
#  'กองระบบท่อระบายน้ำ สำนักการระบายน้ำ',
#  'ฝ่ายเทศกิจ เขตภาษีเจริญ',
#  'เขตธนบุรี',
#  'ศูนย์ก่อสร้างและบูรณะถนน 3 ส่วนก่อสร้างและบูรณะ 1 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)',
#  'ฝ่ายเทศกิจ เขตจตุจักร',
#  'ฝ่ายโยธา เขตพญาไท',
#  'การรถไฟแห่งประเทศไทย',
#  'ผอ.เขตคลองสาน (ว่าที่ ร.ต.สรวุฒิ)',
#  'ผอ.เขตธนบุรี (ว่าที่ ร.ต.เดชาธร)',
#  'เขตมีนบุรี',
#  'เขตบางกะปิ',
#  'กลุ่มงานสัญญาณไฟจราจร สวจ.สจส. กทม.',
#  'สถิติวิจัย) กองบังคับการตำรวจจราจร (กก.5 บก.จร.)',
#  'งานสายตรวจ 2 กองกำกับการ 1 กองบังคับการตำรวจจราจร (งานสายตรวจ 2 กก.1 บก.จร.)',
#  'งานตรวจพิสูจน์ผู้ขับขี่ กก.5 บก.จร.',
#  'กรมทางหลวง',
#  'ฝ่ายโยธา เขตยานนาวา',
#  'ฝ่ายโยธา เขตประเวศ',
#  'การไฟฟ้านครหลวง MEA',
#  'เขตราชเทวี',
#  'เขตหลักสี่',
#  'เขตหนองจอก',
#  'การไฟฟ้านครหลวง เขตมีนบุรี',
#  'ฝ่ายโยธา เขตวัฒนา',
#  'เขตจอมทอง',
#  'กลุ่มงานรักษาที่สาธารณะ ฝ่ายโยธา@ห้วยขวาง',
#  'ฝ่ายรักษาความสะอาดฯ เขตพญาไท',
#  'ฝ่ายโยธา เขตคันนายาว',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางคอแหลม',
#  'ฝ่ายเทศกิจ เขตปทุมวัน',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางกอกน้อย',
#  'บริษัท โทรคมนาคมแห่งชาติ จำกัด (มหาชน)',
#  'ฝ่ายปกครอง เขตคลองสามวา',
#  'ฝ่ายเทศกิจ เขตพระโขนง',
#  'เขตคลองเตย',
#  'การไฟฟ้านครหลวง เขตบางขุนเทียน',
#  'กองบังคับการตำรวจนครบาล 3 (บก.น.3)',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตดอนเมือง',
#  'การไฟฟ้านครหลวง เขตบางนา',
#  'ฝ่ายเทศกิจ เขตยานนาวา',
#  'ฝ่ายเทศกิจ เขตบางเขน',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตห้วยขวาง',
#  'กผ3 สวจ.',
#  'สำนักงานประปาสาขาสุวรรณภูมิ สสสภ.',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางนา',
#  'เขตตลิ่งชัน',
#  'ฝ่ายรักษาความสะอาดฯ เขตพระนคร',
#  'สน.ประเวศ',
#  'ฝ่ายเทศกิจ เขตคลองเตย',
#  'ฝ่ายเทศกิจ เขตห้วยขวาง',
#  'สน.พลับพลาไชย 1',
#  'ฝ่ายรักษาความสะอาดฯ เขตดอนเมือง',
#  'ฝ่ายเทศกิจ เขตธนบุรี',
#  'ฝ่ายพัฒนาชุมชนฯ เขตธนบุรี',
#  'สำนักงานประปาสาขามีนบุรี สสมบ.',
#  'การไฟฟ้านครหลวง เขตบางใหญ่',
#  'ฝ่ายรักษาความสะอาดฯ เขตคันนายาว',
#  'โครงการพระราม 3 ช่วงสะพานกรุงเทพ - ช่วงสะพานพระราม 9',
#  'สน.ตลาดพลู',
#  'ฝ่ายรักษาความสะอาดฯ เขตทุ่งครุ',
#  'กองนโยบายและแผนงาน กน.สจส. กทม.',
#  'พรรคประชาชน เขตบางรัก',
#  'สน.ดินแดง',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตคลองเตย',
#  'สปน.สสภ.',
#  'สำนักงานประปาสาขาภาษีเจริญ สสภ.',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางแค',
#  'การโยธา',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตสายไหม',
#  'ฝ่ายเทศกิจ เขตหลักสี่',
#  'ฝ่ายรักษาความสะอาดฯ เขตราษฎร์บูรณะ',
#  'สน.ดอนเมือง',
#  'ศูนย์ถ่ายทำภาพยนตร์ เขตสายไหม',
#  'สำนักงานสวนสาธารณะ สำนักสิ่งแวดล้อม',
#  'ฝ่ายเทศกิจ เขตบางกอกใหญ่',
#  'การไฟฟ้านครหลวง เขตบางพลี',
#  'นวลจันทร์',
#  'ฟขข.รับร้องเรียนฟุตบาท+ฝาท่อ',
#  'สำนักเทศกิจ กทม.',
#  'งานสายตรวจ 1 กองกำกับการ 1 กองบังคับการตำรวจจราจร (งานสายตรวจ 1 กก.1 บก.จร.)',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตปทุมวัน',
#  'สน.สำราญราษฎร์',
#  'โรงพยาบาลราชพิพัฒน์ สำนักการแพทย์',
#  'สำนักงาน ป.ป.ท.',
#  'ส่วนวิศวกรรมทาง 1 สำนักงานวิศวกรรมทาง (สวก.สนย.)',
#  'บริษัท โทรคมนาคมแห่งชาติ จำกัด (มหาชน) จังหวัดนครพนม',
#  'ฝ่ายรายได้ เขตวังทองหลาง',
#  'ฝ่ายพัฒนาชุมชนฯ เขตวังทองหลาง',
#  'ฝ่ายรายได้ เขตบางแค',
#  'ศูนย์อำนวยการบรรเทาสาธารณภัย ส่วนกลาง',
#  'ทศท',
#  'สำนักงานการเจ้าหน้าที่ สำนักปลัดกรุงเทพมหานคร',
#  'กองการกีฬา สำนักวัฒนธรรม กีฬา และการท่องเที่ยว',
#  '!@฿',
#  'ทดสอบ123',
#  'อำเภอพระประแดง',
#  'สำนักงานตลาดกรุงเทพมหานคร',
#  'สำนักยุทธศาสตร์และประเมินผล กทม.',
#  'โครงการพื้นที่ชั้นใน',
#  'สำนักการประปา',
#  'สำนักอนามัย',
#  'การเคหะแห่งชาติ',
#  'ฝ่ายสิ่งแวดล้อม แขวงจอมพล จตุจักร',
#  'ฝ่ายรายได้ เขตดอนเมือง',
#  'กผ3 สวจ. สจส. กทม.',
#  'ฝ่ายพัฒนาชุมชนฯ เขตห้วยขวาง',
#  'สวนหลวง (Suanluang)',
#  'ฝ่ายรักษาความสะอาดฯ เขตสัมพันธวงศ์',
#  'ฝ่ายพัฒนาชุมชนฯ เขตพระนคร',
#  'สำนักงานประปาสาขาบางเขน สสข.',
#  'สน.ฉลองกรุง',
#  'งานจราจร สน.บางซื่อ',
#  'เทศกิจ(เขต สะพานสูง)',
#  'ตำรวจท่องเที่ยว ส.ทท.3 กก.1 บก.ทท.1',
#  'ศูนย์บริการการแพทย์ฉุกเฉินกรุงเทพมหานคร (ศูนย์เอราวัณ) สำนักการแพทย์',
#  'ฝ่ายทะเบียน เขตสายไหม',
#  'กองสารสนเทศระบายน้ำ สำนักการระบายน้ำ',
#  'พนักงานกวาด เขตบางบอน',
#  'ฝ่ายพัฒนาชุมชนฯ เขตลาดกระบัง',
#  'ฝ่ายพัฒนาชุมชนฯ เขตดุสิต',
#  'กรมการปกครอง',
#  'พนักงานกวาด เขตบางเขน',
#  'พนักงานกวาด เขตหนองจอก',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตหลักสี่',
#  'ฝ่ายทะเบียน เขตธนบุรี',
#  'ฝ่ายรายได้ เขตบางขุนเทียน',
#  'สำนักงานสถานธนานุบาลกรุงเทพมหานคร (ส่วนกลาง)',
#  'ฝ่ายรายได้ เขตบางบอน',
#  'พนักงานกวาด เขตดินแดง',
#  'ส่วนบริการจัดการสิ่งปฏิกูล สจฝ. สสล.',
#  'ฝ่ายการศึกษา เขตดอนเมือง',
#  'ฝ่ายการศึกษา เขตประเวศ',
#  'อาคาร ฝ่ายโยธา เขตดุสิต',
#  'งาน Security operation รัฐสภา',
#  'ฝ่ายปกครอง เขตคลองสาน',
#  'สำนักงานอำนวยการสาธารณภัย สปภ.',
#  'พนักงานกวาด เขตดุสิต',
#  'ฝ่ายการศึกษา เขตบางเขน',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางพลัด',
#  'ฝ่ายพัฒนาชุมชนฯ เขตหลักสี่',
#  'ฝ่ายการศึกษา เขตบางแค',
#  'ฝ่ายทะเบียน เขตคลองสาน',
#  'กลุ่มงานรักษาที่ ฝ่ายโยธา เขตบางเขน',
#  'สำนักอนามัย (ภายใน)',
#  'ฝ่ายพัฒนาชุมชนฯ เขตทวีวัฒนา',
#  'ฝ่ายรายได้ เขตบางนา',
#  'ฝ่ายรายได้ เขตราชเทวี',
#  'สำนักการโยธา',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบึงกุ่ม',
#  'ฝ่ายทะเบียน เขตบึงกุ่ม',
#  'ฝ่ายทะเบียน เขตบางคอแหลม',
#  'กลุ่มงานเก็บขนมูลฝอย เขตบางเขน',
#  'พรรคก้าวไกล บางซื่อ-ดุสิต กทม.เขต7',
#  'สำนักงานพัฒนาสังคมและความมั่นคงของมนุษย์จังหวัด (พมจ.) ส่วนกลาง',
#  'สส.วีรวุธ รักเที่ยง ประชาชน เขต17',
#  'สำนักงาน เขตบางแค',
#  'ธ.ก.ส. สำนักงานใหญ่',
#  'กลุ่มงานอาคาร (ฝ่ายโยธา เขตบางรัก)',
#  'สถาบันพัฒนาข้าราชการกรุงเทพมหานคร',
#  'สถานีตำรวจทางหลวง 2 กองกำกับการ 8 (ส.ทล.2 กก.8 บก.ทล.)',
#  'กระทรวงการพัฒนาสังคม',
#  'ตำรวจท่องเที่ยว ส.ทท.2 กก.1 บก.ทท.1',
#  'ฝ่ายเทศกิจ สำนักงานเขตดินแดง กรุงเทพมหานคร (SoSafe)',
#  'ฝ่ายเทศกิจ สำนักงานเขตลาดพร้าว กรุงเทพมหานคร (SoSafe)',
#  'ศูนย์ปฏิบัติการสถานการณ์น้ำท่วม อว. (ศปก. อว.)',
#  'ฝ่ายการศึกษา เขตยานนาวา',
#  'สำนักงานเคหะนครหลวง สาขาร่มเกล้า 2',
#  'ฝ่ายปกครอง เขตบางรัก',
#  'แขวงทางหลวงนนทบุรี',
#  'เขตประเวศ',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตประเวศ',
#  'สำนักงานระบบควบคุมน้ำ สำนักการระบายน้ำ',
#  'เขตยานนาวา',
#  'เขตบางแค',
#  'ฝ่ายเทศกิจ เขตประเวศ',
#  'ผอ.เขตบางรัก (ผอ.ธราพร )',
#  'ศูนย์เครื่องมือกล ส่วนก่อสร้างและบูรณะ 2 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)',
#  'กลุ่มงานเครื่องหมายจราจร 1 สวจ.สจส. กทม.',
#  'กลุ่มงานบูรณะสะพานและทางโครงสร้างพิเศษ สำนักงานวิศวกรรมทาง (สวก.สนย.)',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางรัก',
#  'ฝ่ายโยธา เขตวังทองหลาง',
#  'กองบังคับการตำรวจนครบาล 5 (บก.น.5)',
#  'ฝ่ายรักษาความสะอาดฯ เขตลาดพร้าว',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตพระโขนง',
#  'เขตพระนคร',
#  'การประปานครหลวง กปน. (Metropolitan Waterworks Authority - MWA)',
#  'แขวงทางหลวงธนบุรี กรมทางหลวง',
#  'กองบังคับการตำรวจนครบาล 8 (บก.น.8)',
#  'ฝ่ายโยธา เขตพระโขนง',
#  'เขตสัมพันธวงศ์',
#  'สน.บางขุนนนท์',
#  'BTS',
#  'สน.จรเข้น้อย',
#  'ฝ่ายเทศกิจ เขตพญาไท',
#  'ฝ่ายรักษาความสะอาดฯ เขตห้วยขวาง',
#  'สน.บางขุนเทียน',
#  'กลุ่มงานเครื่องหมายจราจร 3 สวจ.สจส. กทม.',
#  'สน.ทุ่งมหาเมฆ',
#  'สน.ลุมพินี',
#  'สน.หนองแขม',
#  'สำนักงานประปาสาขาตากสิน สสต.',
#  'ส่วนวิศวกรรมทาง 2 สำนักงานวิศวกรรมทาง (สวก.สนย.)',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตราชเทวี',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางบอน',
#  'สน.ท่าเรือ',
#  'สำนักงานประปาสาขาบางกอกน้อย สสบ.',
#  'Bangkok Smart Lighting (สำนักการโยธา กทม.)',
#  'สำนักงานประปาสาขาสุขสวัสดิ์ สสว.',
#  'สน.ราษฎร์บูรณะ',
#  'สน.บางโพ',
#  'สซทกรรสสญ',
#  'ฝ่ายควบคุมการส่งและจ่ายน้ำ ฝคจ. การประปานครหลวง',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางกะปิ',
#  'ฝ่ายเทศกิจ เขตบางนา',
#  'ฝ่ายพัฒนาชุมชนฯ เขตพระโขนง',
#  'สำนักระบายน้ำ',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตตลิ่งชัน',
#  'สำนักงานสาธารณสุขกรุงเทพมหานคร (สสจ.กรุงเทพมหานคร)',
#  'สน.บางมด',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางเขน',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางนา',
#  'การไฟฟ้านครหลวงเขตวัดเลียบ',
#  'ตำรวจภูธรภาค 1 (บช.ภ.1)',
#  'บริษัท โทรคมนาคมแห่งชาติ จำกัด (มหาชน) จังหวัดภูเก็ต',
#  'สำนักงานเลขานุการปลัดกรุงเทพมหานคร (สลป.)',
#  'กลุ่มงานวางแผนและออกแบบ 3 สวจ.สจส. กทม.',
#  'ฝ่ายพัฒนาชุมชนฯ เขตสาทร',
#  'สน.บางบอน',
#  'ส่วนสำรวจและออกแบบ สสมบ.',
#  'ศูนย์ประสานงาน จุฬาลงกรณ์มหาวิทยาลัย',
#  'ปภ. เขต 1 ปทุมธานี',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางบอน',
#  'กรมธนารักษ์ : The Treasury Department',
#  'โครงการตามแนวรถไฟฟ้าสายสีเขียว สุขุมวิท 81 - สุขุมวิท 107',
#  'พนักงานกวาด เขตวัฒนา',
#  'สน.ลำหิน',
#  'อบจ.นนทบุรี',
#  'ฝ่ายปกครอง เขตจตุจักร',
#  'ฝ่ายพัฒนาชุมชนฯ เขตสัมพันธวงศ์',
#  'ฝ่ายปกครอง เขตปทุมวัน',
#  'ฝ่ายปกครอง เขตบางคอแหลม',
#  'โรงพยาบาลตากสิน สำนักการแพทย์',
#  'ฝ่ายก่อสร้าง การไฟฟ้านครหลวง (ฝกส. กฟน.)',
#  'กลุ่มงานควบคุมอาคาร 2 ส่วนควบคุมอาคาร 2 สำนักงานควบคุมอาคาร (สคอ.สนย.)',
#  'ฝ่ายทะเบียน เขตจอมทอง',
#  'ฝ่ายรายได้ เขตยานนาวา',
#  'ฝ่ายปกครอง เขตพระโขนง',
#  'ศูนย์กำจัดมูลฝอยสายไหม กกฝ. สสล.',
#  'สำนักงานปกครองและทะเบียน',
#  'ฝ่ายการศึกษา เขตพญาไท',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางกอกใหญ่',
#  'ฝ่ายปกครอง เขตสายไหม',
#  'ฝ่ายรายได้ เขตคลองสามวา',
#  'สส. วิทวัส ติชะวาณิชย์ ก้าวไกล',
#  'สำนักงานเขตประเวศ',
#  'กองปฏิบัติการดับเพลิงและกู้ภัย 2 สปภ.',
#  'โครงการถนนวิทยุ',
#  'สถานีดับเพลิงและกู้ภัยภูเขาทอง',
#  'ทีมหมิวก้าวไกล',
#  'ตลาดนัดจตุจักร - ศูนย์บรรเทาทุกข์',
#  'ฝ่ายรายได้ เขตบางเขน',
#  'ฝ่ายการศึกษา เขตบางขุนเทียน',
#  'กองปฏิบัติการดับเพลิงและกู้ภัย 5 สปภ.',
#  'ฝ่ายการศึกษา เขตบางพลัด',
#  'โครงการส่วนต่อขยายตามแนวรถไฟฟ้าสายสีม่วง ถ.กรุงเทพ-นนทบุรี-ถ.ติวานนท์',
#  'ศูนย์วิทยุพระราม สายด่วน 199',
#  'ส่วนวัฒนธรรม สำนักงานวัฒนธรรมและการท่องเที่ยว สำนักวัฒนธรรม กีฬา และการท่องเที่ยว',
#  'ฝ่ายทะเบียน เขตลาดพร้าว',
#  'ฝ่ายปกครอง เขตบางแค',
#  'ฝ่ายการศึกษา เขตบางบอน',
#  'โรงพยาบาลนคราภิบาล สำนักการแพทย์',
#  'ฝบค. กฟน',
#  'ฝ่ายปกครอง เขตจอมทอง',
#  'ฝ่ายปกครอง เขตสัมพันธวงศ์',
#  'ฝ่ายปกครอง เขตคันนายาว',
#  'กลุ่มงานไฟฟ้าสาธารณะ การไฟฟ้านครหลวงเขตบางนา',
#  'สำนักงานเขตบางเขน กรุงเทพมหานคร (SoSafe)',
#  'ฝ่ายเทศกิจ สำนักงานเขตธนบุรี กรุงเทพมหานคร (SoSafe)',
#  'ฝ่ายปกครอง เขตภาษีเจริญ',
#  'สำนักงานเขตพญาไท',
#  'กระทรวงการท่องเที่ยวและกีฬา',
#  'สำนักงานเขตลาดพร้าว',
#  'กองบังคับการตำรวจนครบาล 9 (บก.น.9)',
#  'สำนักการโยธา กทม.',
#  'เขตจตุจักร',
#  'เขตลาดพร้าว',
#  'เขตสวนหลวง',
#  'ฝ่ายเทศกิจ เขตคลองสาน',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางแค',
#  'สำนักงานวิศวกรรมจราจร สวจ.สจส. กทม.',
#  'การไฟฟ้านครหลวง ฝ่ายบริหารโครงการ',
#  'ฝ่ายเทศกิจ เขตคลองสามวา',
#  'สำนักงานวิศวกรรมทาง สำนักการโยธา (สวก.สนย.) กทม.',
#  'ฝ่ายเทศกิจ เขตราชเทวี',
#  'เขตวัฒนา',
#  'ฝ่ายโยธา เขตสาทร',
#  'ฝ่ายเทศกิจ เขตลาดพร้าว',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตลาดพร้าว',
#  'ฝ่ายโยธา เขตบางพลัด',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางซื่อ',
#  'ฝ่ายเทศกิจ เขตวัฒนา',
#  'การไฟฟ้านครหลวง เขตธนบุรี',
#  'ฝ่ายโยธา เขตพระนคร',
#  'เขตบางคอแหลม',
#  'สำนักงานจัดการคุณภาพน้ำ สำนักการระบายน้ำ',
#  'ฝ่ายโยธา เขตบางแค',
#  'เขตบางบอน',
#  'ฝ่ายโยธา เขตสวนหลวง',
#  'ศูนย์ก่อสร้างและบูรณะถนน 3 ส่วนก่อสร้างและบูรณะ 2 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)',
#  'ฝ่ายเทศกิจ เขตจอมทอง',
#  'กองโครงการสายอากาศเป็นสายใต้ดิน3 ฝ่ายบริหารโครงการ การไฟฟ้านครหลวง (กคต.3 ฝบค. กฟน.)',
#  'การไฟฟ้านครหลวง เขตราษฎร์บูรณะ',
#  'ฝ่ายรักษาความสะอาดฯ เขตบางรัก',
#  'ฝ่ายเทศกิจ เขตป้อมปราบศัตรูพ่าย',
#  'ฝ่ายพัฒนาชุมชนฯ เขตลาดพร้าว',
#  'ฝ่ายรักษาความสะอาดฯ เขตสาทร',
#  'ฝ่ายรักษาความสะอาดฯ เขตดุสิต',
#  'ฝ่ายรักษาความสะอาดฯ เขตตลิ่งชัน',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตธนบุรี',
#  'สน.สุทธิสาร',
#  'ปัญหาที่ต้องแก้เชิงนโยบาย',
#  'ฝ่ายเทศกิจ เขตคันนายาว',
#  'ฝ่ายสิ่งแวดล้อม แขวงลาดยาว จตุจักร',
#  'กองโครงการสายอากาศเป็นสายใต้ดิน2 ฝ่ายบริหารโครงการ การไฟฟ้านครหลวง (กคต.2 ฝบค. กฟน.)',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางกอกใหญ่',
#  'สน.บางรัก',
#  'สำนักงานประปาสาขาทุ่งมหาเมฆ สสท.',
#  'ฝ่ายปกครอง เขตพญาไท',
#  'โครงการพระราม 4',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตสะพานสูง',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางคอแหลม',
#  'ฝ่ายโยธา เขตปทุมวัน',
#  'ฝ่ายเทศกิจ เขตลาดกระบัง',
#  'สำนักงานควบคุมอาคาร สำนักการโยธา (สคอ.สนย.) กทม.',
#  'กองระบบเทคโนโลยีจราจร กทจ.สจส. กทม.',
#  'สำนักงานประปาสาขาแม้นศรี สสม.',
#  'กองโครงการบ่อพักและท่อร้อยสายใต้ดิน ฝ่ายออกแบบระบบไฟฟ้าและงานวิศวกรรมโยธา การไฟฟ้านครหลวง (กคบ. ฝอบ. กฟน.)',
#  'กลุ่มงานเทคโนโลยีจราจร 1 กทจ.สจส. กทม.',
#  'สน.ประชาชื่น',
#  'กรมทางหลวงชนบท กระทรวงคมนาคม',
#  'งานสายตรวจ 3 กองกำกับการ 1 กองบังคับการตำรวจจราจร (งานสายตรวจ 3 กก.1 บก.จร.)',
#  'ฝ่ายพัฒนาชุมชนฯ เขตคลองเตย',
#  'สำนักวัฒนธรรม กีฬาและการท่องเที่ยว กทม.',
#  'ฝ่ายเทศกิจ เขตหนองแขม',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตดุสิต',
#  'หน่วยซ่อมบำรุงเร่งด่วน',
#  'พนักงานกวาด เขตตลิ่งชัน',
#  'สน.วิภาวดี งานศูนย์ควบคุมจราจรวิภาวดีรังสิต/ทางพิเศษ กก.2 บก.จร.',
#  'ฝ่ายพัฒนาชุมชนฯ เขตคันนายาว',
#  'สำนักงานพัฒนาระบบสารสนเทศดิจิทัล สดท.',
#  'ฝ่ายรักษาความสะอาดฯ เขตหนองแขม',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางเขน',
#  'ฝ่ายโยธา เขตบางขุนเทียน',
#  'สำนักงานพระพุทธศาสนาแห่งชาติ',
#  'สภ.พระประแดง',
#  'ตำรวจภูธรจังหวัดสมุทรปราการ (ภ.จว.สมุทรปราการ)',
#  'กองบริการผู้ใช้ไฟฟ้า การไฟฟ้านครหลวงเขตลาดกระบัง',
#  'ฝ่ายสิ่งแวดล้อม แขวงจตุจักร จตุจักร',
#  'ส.ส.อุ๋ม ธณิกานต์ เขตบางซื่อ',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบึงกุ่ม',
#  'สำนักงานเขตจอมทอง',
#  'สำนักการวางผังและพัฒนาเมือง กทม.',
#  'กลุ่มงานตกแต่ง สำนักงานออกแบบ (สอบ.สนย.)',
#  'สำนักงานเลขานุการผู้ว่าราชการกรุงเทพ',
#  'เทศบาลตำบลสำโรงเหนือ จ.สมุทรปราการ',
#  'กองกำกับการ 2 (ศูนย์ควบคุมจราจรทางด่วน ทางพิเศษ) กองบังคับการตำรวจจราจร (กก.2 บก.จร.)',
#  'MRTA',
#  'สำนักจราจรและขนส่ง',
#  'อำเภอบางกรวย',
#  'จังหวัดนนทบุรี',
#  'ฝ่ายสิ่งแวดล้อมฯ เขตบางขุนเทียน',
#  'ฝ่ายการศึกษา เขตตลิ่งชัน',
#  'ฝ่ายปกครอง เขตบางเขน',
#  'ฝ่ายการศึกษา เขตบางกะปิ',
#  'พนักงานกวาด เขตยานนาวา',
#  'กองจัดการคุณภาพอากาศและเสียง สำนักสิ่งแวดล้อม',
#  'ฝ่ายพัฒนาชุมชนฯ เขตวัฒนา',
#  'กองโครงการสถานีไฟฟ้า ฝ่ายออกแบบระบบไฟฟ้าและงานวิศวกรรมโยธา การไฟฟ้านครหลวง (กคฟ. ฝอบ. กฟน.)',
#  'สภ.รัตนาธิเบศร์',
#  'กระทรวงสาธารณสุข',
#  'ฝ่ายปกครอง เขตบางกอกใหญ่',
#  'สำนักงานเขตยานนาวา',
#  'พนักงานกวาด เขตคลองสามวา',
#  'ฝ่ายปกครอง เขตบางขุนเทียน',
#  'ฝ่ายการศึกษา เขตหลักสี่',
#  'ฝ่ายพัฒนาชุมชนฯ เขตบางเขน',
#  'สส.กฤษฐ์หิรัญ-ประชาชน นครสวรรค์\xa0',
#  'โครงการตามแนวรถไฟฟ้าสายสีส้ม สัญญา 3',
#  'พนักงานกวาด เขตคลองสาน',
#  'ฝ่ายทะเบียน เขตดินแดง',
#  'ฝ่ายการศึกษา เขตทวีวัฒนา',
#  'สำนักการศึกษา สนศ.กทม.',
#  'พนักงานกวาด เขตพระนคร',
#  'ฝ่ายรายได้ เขตจตุจักร',
#  'วชิรพยาบาล กทม.',
#  'ฝ่ายทะเบียน เขตหนองแขม',
#  'รองปลัดฯ นางวันทนีย์ วัฒนะ',
#  'ฝ่ายรายได้ เขตดินแดง',
#  'สามย่าน (Samyan)',
#  'ตำรวจท่องเที่ยว ส.ทท.1 กก.1 บก.ทท.1',
#  'พนักงานกวาด เขตธนบุรี',
#  'ฝ่ายการศึกษา เขตพระโขนง',
#  'โครงการถนนประชาราษฎร์สาย 2',
#  'สำนักงานเลขานุการ สำนักการแพทย์',
#  'ฝ่ายรายได้ เขตทวีวัฒนา',
#  'ฝ่ายทะเบียน เขตบางแค',
#  'สำนักปลัด กทม.',
#  'โครงการตามแนวรถไฟฟ้าสายสีชมพู (รามอินทรา - มีนบุรี)',
#  'TFD Personal Auditor',
#  'ฝ่ายการตลาดและลูกค้าสัมพันธ์ ฝตส.',
#  'โครงการ DB เทศบาลสงเคราะห์-ประชาชื่น ฝอบ. กฟน.',
#  'โรงพยาบาลหลวงพ่อทวีศักดิ์ ชุตินฺธโร อุทิศ สำนักการแพทย์',
#  'สภาเด็กและเยาวชนกรุงเทพมหานคร',
#  'สำนักงาน กสทช. (รท.)',
#  'สำนักงาน กสทช. (บริการกิจการกระจายเสียงและโทรทัศน์)',
#  'ฝ่ายการคลัง เขตบางบอน',
#  'สน.บางพลัด1',
#  'สำนังานเขตทวีวัฒนา',
#  'ฝ่ายโยธา เขตห้วยขวาง',
#  ...]

# %%
pathOrgsLoc = 'org_with_loc_v2.csv'
dfOrg = spark.read.csv(pathOrgsLoc, header=True, inferSchema=True)
dfOrg.printSchema()

# prepare org location dictionary for fast lookup
org_loc = {row['organization_raw']: (row['latitude'], row['longitude']) for row in dfOrg.collect()}
# Out:
# root
#  |-- organization_raw: string (nullable = true)
#  |-- displayName: string (nullable = true)
#  |-- formattedAddress: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)

# %%
from pyspark.sql.types import ArrayType, StringType
# only keep organizations that have valid locations in the org_loc dictionary
def filter_orgs(orgs):
    filtered = []
    if orgs is None:
        return filtered
    for org in orgs:
        loc = org_loc.get(org)
        if loc and loc[0] != "Not Found" and loc[1] != "Not Found":
            filtered.append(org)
    return filtered

filter_orgs_udf = F.udf(filter_orgs, ArrayType(StringType()))

# apply filter to the array
df = df.withColumn('organization_array', filter_orgs_udf(col('organization_array')))

# %%
print("sample after filter organization:")
df.filter(col('organization').like('%Traffy @ ITS Lab2%')).select('organization', 'organization_array', 'latitude', 'longitude').show(5, truncate=False  )
# Out:
# sample after filter organization:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------+--------+---------+
# |organization                                                                                                                                                                                                 |organization_array                                                                                                                              |latitude|longitude|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------+--------+---------+
# |Traffy @ ITS Lab2,เขตดอนเมือง,สำนักการจราจรและขนส่ง กรุงเทพมหานคร (สจส. กทม.),ฝ่ายโยธา เขตดอนเมือง,กลุ่มงานเครื่องหมายจราจร 1 สวจ.สจส. กทม.,ผอ.เขตดอนเมือง (นายสาโรจน์),กลุ่มกรุงเทพเหนือ (นางวันทนีย์ วัฒนะ)|[เขตดอนเมือง, สำนักการจราจรและขนส่ง กรุงเทพมหานคร (สจส. กทม.), ฝ่ายโยธา เขตดอนเมือง, กลุ่มงานเครื่องหมายจราจร 1 สวจ.สจส. กทม.]                  |13.91574|100.59816|
# |Traffy @ ITS Lab2,เขตบางขุนเทียน,ฝ่ายเทศกิจ เขตบางขุนเทียน                                                                                                                                                   |[เขตบางขุนเทียน, ฝ่ายเทศกิจ เขตบางขุนเทียน]                                                                                                     |13.62663|100.44574|
# |Traffy @ ITS Lab2,เขตทวีวัฒนา,สำนักการโยธา กทม.,กองควบคุมการก่อสร้าง สำนักการโยธา (กคส.สนย.) กทม.,กลุ่มงานควบคุมการก่อสร้าง 4 กองควบคุมการก่อสร้าง (กคส.สนย.)                                                |[เขตทวีวัฒนา, สำนักการโยธา กทม., กองควบคุมการก่อสร้าง สำนักการโยธา (กคส.สนย.) กทม., กลุ่มงานควบคุมการก่อสร้าง 4 กองควบคุมการก่อสร้าง (กคส.สนย.)]|13.75322|100.38861|
# |Traffy @ ITS Lab2,เขตจอมทอง,ฝ่ายเทศกิจ เขตจอมทอง                                                                                                                                                             |[เขตจอมทอง, ฝ่ายเทศกิจ เขตจอมทอง]                                                                                                               |13.67674|100.45936|
# |Traffy @ ITS Lab2,เขตลาดกระบัง,เขตสะพานสูง,สำนักการระบายน้ำ กทม.,ฝ่ายโยธา เขตลาดกระบัง,ฝ่ายโยธา เขตสะพานสูง,กองระบบคลอง สำนักการระบายน้ำ,ผอ.เขตสะพานสูง (นายสุพจน์),กลุ่มกรุงเทพตะวันออก (นายณรงค์ เรืองศรี) |[เขตลาดกระบัง, เขตสะพานสูง, สำนักการระบายน้ำ กทม., ฝ่ายโยธา เขตลาดกระบัง, ฝ่ายโยธา เขตสะพานสูง, กองระบบคลอง สำนักการระบายน้ำ]                   |13.77479|100.71682|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------+--------+---------+
# only showing top 5 rows

# %%
# 1) explode the organization_array to one org per row
df_org = df.withColumn("org", F.explode_outer("organization_array"))

# 2) count in how many tickets each org appears
org_counts = (
    df_org
    .groupBy("org")
    .agg(F.countDistinct("ticket_id").alias("ticket_count"))
    .filter(F.col("org").isNotNull())
)

# 3) pick top 150 most frequent orgs
TOP_N = 150
top150 = org_counts.orderBy(F.desc("ticket_count")).limit(TOP_N)
top150.show(top150.count(), truncate=False)

top_org_rows = top150.collect()

top_orgs = [row["org"] for row in top_org_rows]
# Out:
# +-------------------------------------------------------------------------------------+------------+
# |org                                                                                  |ticket_count|
# +-------------------------------------------------------------------------------------+------------+
# |สำนักการโยธา กทม.                                                                    |65231       |
# |สำนักงานตำรวจแห่งชาติ (Royal Thai Police)                                            |49766       |
# |กองบัญชาการตำรวจนครบาล (บช.น.)                                                       |49754       |
# |การไฟฟ้านครหลวง MEA                                                                  |39809       |
# |สำนักงานก่อสร้างและบูรณะ สำนักการโยธา (สกบ.สนย.) กทม.                                |24798       |
# |สำนักการจราจรและขนส่ง กรุงเทพมหานคร (สจส. กทม.)                                      |21774       |
# |สำนักสิ่งแวดล้อม กทม.                                                                |12885       |
# |สำนักการระบายน้ำ กทม.                                                                |12286       |
# |ศูนย์เครื่องมือกล ส่วนก่อสร้างและบูรณะ 1 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)         |11980       |
# |กองบังคับการตำรวจนครบาล 5 (บก.น.5)                                                   |11059       |
# |ศูนย์เครื่องมือกล ส่วนก่อสร้างและบูรณะ 2 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)         |10489       |
# |กองบังคับการตำรวจนครบาล 2 (บก.น.2)                                                   |8988        |
# |ฝ่ายโยธา เขตประเวศ                                                                   |7814        |
# |ฝ่ายโยธา เขตจตุจักร                                                                  |7525        |
# |Bangkok Smart Lighting (สำนักการโยธา กทม.)                                           |7227        |
# |กองแผนงานและประสานสาธารณูปโภค สำนักการโยธา (กผภ.สนย.) กทม.                           |7089        |
# |กรมทางหลวง                                                                           |6321        |
# |ฝ่ายเทศกิจ เขตจตุจักร                                                                |6244        |
# |ฝ่ายโยธา เขตวัฒนา                                                                    |6184        |
# |การประปานครหลวง กปน. (Metropolitan Waterworks Authority - MWA)                       |5710        |
# |กองระบบท่อระบายน้ำ สำนักการระบายน้ำ                                                  |5677        |
# |ฝ่ายเทศกิจ เขตบางแค                                                                  |5666        |
# |กลุ่มงานสัญญาณไฟจราจร สวจ.สจส. กทม.                                                  |5630        |
# |ฝ่ายเทศกิจ เขตสาทร                                                                   |5380        |
# |ฝ่ายโยธา เขตบางเขน                                                                   |5045        |
# |ฝ่ายโยธา เขตคลองสามวา                                                                |5009        |
# |ศูนย์ก่อสร้างและบูรณะถนน 1 ส่วนก่อสร้างและบูรณะ 1 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)|4943        |
# |กองบังคับการตำรวจนครบาล 1 (บก.น.1)                                                   |4940        |
# |ฝ่ายโยธา เขตบางกะปิ                                                                  |4936        |
# |การไฟฟ้านครหลวง เขตบางเขน                                                            |4925        |
# |ฝ่ายเทศกิจ เขตปทุมวัน                                                                |4885        |
# |บริษัท โทรคมนาคมแห่งชาติ จำกัด (มหาชน)                                               |4773        |
# |การรถไฟฟ้าขนส่งมวลชนแห่งประเทศไทย (รฟม.)                                             |4740        |
# |กองบังคับการตำรวจนครบาล 6 (บก.น.6)                                                   |4713        |
# |ฝ่ายเทศกิจ เขตวัฒนา                                                                  |4672        |
# |กองบังคับการตำรวจนครบาล 4 (บก.น.4)                                                   |4670        |
# |ฝ่ายโยธา เขตสวนหลวง                                                                  |4495        |
# |ฝ่ายเทศกิจ เขตประเวศ                                                                 |4432        |
# |ฝ่ายเทศกิจ เขตพระนคร                                                                 |4401        |
# |กองบังคับการตำรวจนครบาล 9 (บก.น.9)                                                   |4384        |
# |ศูนย์ก่อสร้างและบูรณะถนน 3 ส่วนก่อสร้างและบูรณะ 1 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)|4339        |
# |สน.ลุมพินี                                                                           |4336        |
# |สำนักงานสัตวแพทย์สาธารณสุข สำนักอนามัย กทม.                                          |4329        |
# |ฝ่ายเทศกิจ เขตบางกอกน้อย                                                             |4218        |
# |กองบังคับการตำรวจนครบาล 7 (บก.น.7)                                                   |4170        |
# |การไฟฟ้านครหลวง เขตธนบุรี                                                            |4153        |
# |ฝ่ายเทศกิจ เขตคลองเตย                                                                |4137        |
# |การไฟฟ้านครหลวง ฝ่ายบริหารโครงการ                                                    |4128        |
# |ฝ่ายโยธา เขตลาดพร้าว                                                                 |4081        |
# |ฝ่ายโยธา เขตบางซื่อ                                                                  |3994        |
# |การไฟฟ้านครหลวง เขตมีนบุรี                                                           |3958        |
# |ฝ่ายเทศกิจ เขตป้อมปราบศัตรูพ่าย                                                      |3950        |
# |ฝ่ายเทศกิจ เขตบึงกุ่ม                                                                |3936        |
# |ฝ่ายโยธา เขตพระโขนง                                                                  |3932        |
# |ศูนย์ควบคุมระบบป้องกันน้ำท่วม กทม.                                                   |3920        |
# |กองบังคับการตำรวจนครบาล 8 (บก.น.8)                                                   |3917        |
# |การไฟฟ้านครหลวง เขตบางขุนเทียน                                                       |3782        |
# |กรมควบคุมมลพิษ                                                                       |3766        |
# |ฝ่ายโยธา เขตบางแค                                                                    |3687        |
# |สำนักงานวิศวกรรมจราจร สวจ.สจส. กทม.                                                  |3662        |
# |ฝ่ายโยธา เขตบึงกุ่ม                                                                  |3608        |
# |ฝ่ายโยธา เขตสายไหม                                                                   |3596        |
# |ฝ่ายโยธา เขตสะพานสูง                                                                 |3595        |
# |ฝ่ายเทศกิจ เขตบางเขน                                                                 |3524        |
# |ฝ่ายรักษาความสะอาดฯ เขตจตุจักร                                                       |3467        |
# |ฝ่ายโยธา เขตบางขุนเทียน                                                              |3433        |
# |การไฟฟ้านครหลวง เขตบางกะปิ                                                           |3384        |
# |ฝ่ายโยธา เขตมีนบุรี                                                                  |3337        |
# |การไฟฟ้านครหลวง เขตสามเสน                                                            |3328        |
# |ฝ่ายโยธา เขตคลองเตย                                                                  |3302        |
# |ฝ่ายเทศกิจ เขตดินแดง                                                                 |3287        |
# |ฝ่ายโยธา เขตบางคอแหลม                                                                |3285        |
# |ฝ่ายโยธา เขตวังทองหลาง                                                               |3275        |
# |ฝ่ายโยธา เขตดินแดง                                                                   |3234        |
# |ฝ่ายเทศกิจ เขตบางรัก                                                                 |3209        |
# |ศูนย์ก่อสร้างและบูรณะถนน 3 ส่วนก่อสร้างและบูรณะ 2 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)|3203        |
# |ฝ่ายโยธา เขตพญาไท                                                                    |3099        |
# |ศูนย์ก่อสร้างและบูรณะถนน 2 ส่วนก่อสร้างและบูรณะ 2 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)|3088        |
# |ฝ่ายเทศกิจ เขตราชเทวี                                                                |3084        |
# |ฝ่ายโยธา เขตห้วยขวาง                                                                 |3070        |
# |กองบังคับการตำรวจนครบาล 3 (บก.น.3)                                                   |3046        |
# |ฝ่ายเทศกิจ เขตหนองแขม                                                                |2990        |
# |การไฟฟ้านครหลวง เขตลาดกระบัง                                                         |2837        |
# |กลุ่มงานเครื่องหมายจราจร 1 สวจ.สจส. กทม.                                             |2793        |
# |กองควบคุมการก่อสร้าง สำนักการโยธา (กคส.สนย.) กทม.                                    |2776        |
# |ฝ่ายเทศกิจ เขตภาษีเจริญ                                                              |2755        |
# |ฝ่ายโยธา เขตตลิ่งชัน                                                                 |2754        |
# |สน.ทองหล่อ                                                                           |2701        |
# |ฝ่ายเทศกิจ เขตยานนาวา                                                                |2678        |
# |ฝ่ายเทศกิจ เขตคลองสามวา                                                              |2666        |
# |ฝ่ายโยธา เขตดอนเมือง                                                                 |2600        |
# |ฝ่ายโยธา เขตบางรัก                                                                   |2578        |
# |ฝ่ายโยธา เขตสาทร                                                                     |2515        |
# |สน.พญาไท                                                                             |2505        |
# |ฝ่ายรักษาความสะอาดฯ เขตสายไหม                                                        |2485        |
# |ฝ่ายโยธา เขตพระนคร                                                                   |2465        |
# |กองระบบคลอง สำนักการระบายน้ำ                                                         |2462        |
# |ฝ่ายโยธา เขตทุ่งครุ                                                                  |2456        |
# |ฝ่ายโยธา เขตหลักสี่                                                                  |2422        |
# |การไฟฟ้านครหลวง เขตนวลจันทร์                                                         |2373        |
# |ศูนย์ก่อสร้างและบูรณะถนน 2 ส่วนก่อสร้างและบูรณะ 1 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)|2361        |
# |การไฟฟ้านครหลวง เขตบางนา                                                             |2323        |
# |ฝ่ายโยธา เขตบางนา                                                                    |2321        |
# |ฝ่ายเทศกิจ เขตวังทองหลาง                                                             |2254        |
# |การไฟฟ้านครหลวง เขตคลองเตย                                                           |2245        |
# |ฝ่ายเทศกิจ เขตบางกะปิ                                                                |2242        |
# |ฝ่ายเทศกิจ เขตธนบุรี                                                                 |2227        |
# |ฝ่ายรักษาความสะอาดฯ เขตบางรัก                                                        |2191        |
# |ฝ่ายรักษาความสะอาดฯ เขตบางกะปิ                                                       |2188        |
# |ฝ่ายโยธา เขตยานนาวา                                                                  |2187        |
# |สำนักอนามัย กทม.                                                                     |2172        |
# |ฝ่ายรักษาความสะอาดฯ เขตลาดพร้าว                                                      |2169        |
# |การไฟฟ้านครหลวง เขตยานนาวา                                                           |2155        |
# |การไฟฟ้านครหลวง เขตราษฎร์บูรณะ                                                       |2144        |
# |ฝ่ายรักษาความสะอาดฯ เขตบางซื่อ                                                       |2143        |
# |ฝ่ายเทศกิจ เขตพญาไท                                                                  |2115        |
# |ฝ่ายสิ่งแวดล้อมฯ เขตจตุจักร                                                          |2113        |
# |ศูนย์ก่อสร้างและบูรณะถนน 1 ส่วนก่อสร้างและบูรณะ 2 สำนักงานก่อสร้างและบูรณะ (สกบ.สนย.)|2082        |
# |ฝ่ายโยธา เขตบางบอน                                                                   |2072        |
# |ฝ่ายรักษาความสะอาดฯ เขตประเวศ                                                        |2070        |
# |ฝ่ายเทศกิจ เขตดอนเมือง                                                               |2029        |
# |สำนักงานสวนสาธารณะ สำนักสิ่งแวดล้อม                                                  |2027        |
# |ฝ่ายโยธา เขตคันนายาว                                                                 |2009        |
# |ฝ่ายโยธา เขตหนองแขม                                                                  |2004        |
# |ฝ่ายเทศกิจ เขตบางซื่อ                                                                |1974        |
# |ฝ่ายโยธา เขตภาษีเจริญ                                                                |1956        |
# |กรุงเทพโปร่งใส                                                                       |1948        |
# |ฝ่ายรักษาความสะอาดฯ เขตบางเขน                                                        |1930        |
# |ฝ่ายโยธา เขตราชเทวี                                                                  |1925        |
# |ฝ่ายโยธา เขตทวีวัฒนา                                                                 |1920        |
# |สำนักงานระบบขนส่ง สขส.สจส. กทม.                                                      |1901        |
# |ฝ่ายโยธา เขตธนบุรี                                                                   |1887        |
# |ฝ่ายรักษาความสะอาดฯ เขตวัฒนา                                                         |1883        |
# |ฝ่ายเทศกิจ เขตลาดพร้าว                                                               |1868        |
# |ฝ่ายรักษาความสะอาดฯ เขตบางแค                                                         |1832        |
# |ผอ.เขตธนบุรี (ว่าที่ ร.ต.เดชาธร)                                                     |1822        |
# |ฝ่ายเทศกิจ เขตลาดกระบัง                                                              |1799        |
# |ฝ่ายเทศกิจ เขตบางขุนเทียน                                                            |1798        |
# |ฝ่ายเทศกิจ เขตหลักสี่                                                                |1771        |
# |ฝ่ายสิ่งแวดล้อมฯ เขตลาดกระบัง                                                        |1762        |
# |สน.พหลโยธิน                                                                          |1706        |
# |ฝ่ายรักษาความสะอาดฯ เขตพระนคร                                                        |1694        |
# |ฝ่ายเทศกิจ เขตสายไหม                                                                 |1685        |
# |ฝ่ายโยธา เขตจอมทอง                                                                   |1682        |
# |กลุ่มงานควบคุมการก่อสร้าง 4 กองควบคุมการก่อสร้าง (กคส.สนย.)                          |1655        |
# |กองกำจัดมูลฝอย สำนักสิ่งแวดล้อม                                                      |1640        |
# |สน.บางเขน                                                                            |1631        |
# |ฝ่ายเทศกิจ เขตสวนหลวง                                                                |1626        |
# |ศูนย์กำจัดมูลฝอยอ่อนนุช กกฝ. สสล.                                                    |1617        |
# |ฝ่ายสิ่งแวดล้อมฯ เขตบางขุนเทียน                                                      |1615        |
# +-------------------------------------------------------------------------------------+------------+

# %%
import matplotlib.pyplot as plt
from pyspark.sql import functions as F
from matplotlib import font_manager
plt.rcParams['font.family'] = ['Leelawadee'] 

# Option 2: Using a custom font file by path
# Replace 'path/to/YourForeignFont.ttf' with the actual path
font_path = 'C:/Windows/Fonts/Leelawadee/leelawad.ttf' 
prop = font_manager.FontProperties(fname=font_path)

# %%
# 1) Filter + sort in Spark
org_counts_clean = (
    org_counts
    .filter(F.col("org").isNotNull())
    .orderBy(F.desc("ticket_count"))
    .limit(TOP_N)
)

# 2) Convert to Pandas
pdf = org_counts_clean.toPandas()

# 3) Plot with matplotlib
plt.figure(figsize=(16, 15))
plt.bar(pdf["org"], pdf["ticket_count"])

plt.xlabel("organization")
plt.ylabel("ticket_count")
plt.title("Ticket count per organization")
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
from pyspark.sql import functions as F

# 1) Filter + sort in Spark
org_counts_clean = (
    org_counts
    .filter(F.col("org").isNotNull())
    .orderBy(F.desc("ticket_count"))
)

# 2) Convert to Pandas
pdf = org_counts_clean.toPandas()

# 3) Plot with matplotlib
plt.figure(figsize=(200, 6))
plt.bar(pdf["org"], pdf["ticket_count"])

plt.xlabel("organization")
plt.ylabel("ticket_count")
plt.title("Ticket count per organization")
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()

plt.show()

# %%
# from pyspark.sql.types import ArrayType, StringType

# # put top_orgs into a Python set for fast lookup
# top_orgs_set = set(top_orgs)

# def keep_top_orgs(orgs):
#     if orgs is None:
#         return []
#     return [o for o in orgs if o in top_orgs_set]

# keep_top_orgs_udf = F.udf(keep_top_orgs, ArrayType(StringType()))

# # apply to organization_array
# df = df.withColumn(
#     "organization_array",
#     keep_top_orgs_udf(F.col("organization_array"))
# )

# %% [markdown]
# ## calculate orgs distance

# %%
from pyspark.sql.types import ArrayType, DoubleType, StructField, StructType
import math
from pyspark.sql.functions import udf, col

# calculate haversine distance between two points
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Earth radius in km
    lat1, lon1, lat2, lon2 = map(float, [lat1, lon1, lat2, lon2])
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dphi = math.radians(lat2 - lat1)
    dlambda = math.radians(lon2 - lon1)
    a = math.sin(dphi/2)**2 + math.cos(phi1)*math.cos(phi2)*math.sin(dlambda/2)**2
    return R * 2 * math.atan2(math.sqrt(a), math.sqrt(1 - a))


def calc_distances(orgs, lat, lon):
    if orgs is None or lat is None or lon is None:
        return []
    distances = list()
    for org in orgs:
        loc = org_loc.get(org)
        if loc and loc[0] != "Not Found" and loc[1] != "Not Found":
            try:
                dist = haversine(lat, lon, float(loc[0]), float(loc[1]))
                distances.append(dist)
            except Exception:
                continue
    return distances

def calc_distance_with_coords(org, lat, lon):
    if org is None or lat is None or lon is None:
        return (None, None, None)  # distance, org_lat, org_lon
    
    loc = org_loc.get(org)
    if not loc or loc[0] == "Not Found" or loc[1] == "Not Found":
        return (None, None, None)
    
    try:
        org_lat = float(loc[0])
        org_lon = float(loc[1])
        distance = haversine(lat, lon, org_lat, org_lon)
        return (distance, org_lat, org_lon)
    except Exception:
        return (None, None, None)


schema = StructType([
    StructField("distance_km", DoubleType(), True),
    StructField("organization_latitude", DoubleType(), True),
    StructField("organization_longitude", DoubleType(), True)
])


calc_distance_udf = udf(calc_distance_with_coords, schema)

# %%
# calculate distances into array
# this is for visualization
df = (df
    .withColumn("organization", F.explode("organization_array"))
    .withColumn(
        "org_info",
        calc_distance_udf(
            F.col("organization"),
            F.col("latitude"),
            F.col("longitude")
        )
    ))

df = (
    df
    .withColumn("organization_distance", F.col("org_info.distance_km"))
    .withColumn("organization_latitude", F.col("org_info.organization_latitude"))
    .withColumn("organization_longitude", F.col("org_info.organization_longitude"))
    .drop("org_info", "organization_array", "type")
)

# df = df.withColumn(
#     'organization_distances',
#     calc_distances_udf(col('organization_array'), col('latitude'), col('longitude'))
# )

# %%
df = df.drop("organization_array", "type")

# %%
df.columns
# Out:
# ['ticket_id',
#  'organization',
#  'comment',
#  'photo',
#  'photo_after',
#  'coords',
#  'address',
#  'subdistrict',
#  'district',
#  'province',
#  'timestamp',
#  'state',
#  'star',
#  'count_reopen',
#  'last_activity',
#  'completion_time_hours',
#  'longitude',
#  'latitude',
#  'type_array',
#  'organization_distance',
#  'organization_latitude',
#  'organization_longitude']

# %%
# onehot for organization and its distance to the ticket

ticket_org = (
    df
    .filter(F.col("organization_distance").isNotNull())
    .select("ticket_id", "organization", "organization_distance")
)

# ticket_org.show(2, truncate=False)
# replace commas, spaces, symbols with _ to avoid INVALID_ATTRIBUTE_NAME_SYNTAX column name error
ticket_org = ticket_org.withColumn(
    "organization_clean",
    F.regexp_replace(
        "organization",
        r"[^0-9A-Za-zก-๙_]",
        "_"
    )
)

# add prefix BEFORE pivot
ticket_org = ticket_org.withColumn(
    "org_pivot_key",
    F.concat(F.lit("dist_"), F.col("organization_clean"))
)

# pivot organization to columns
org_wide = (
    ticket_org
    .select("ticket_id", "org_pivot_key", "organization_distance")
    .groupBy("ticket_id")
    .pivot("org_pivot_key")
    .agg(F.first("organization_distance"))
)

# list of organization columns
org_cols = [c for c in org_wide.columns if c != "ticket_id"]

# if organization is not responsible for the ticket, fill -1
org_wide = org_wide.fillna(-1.0, subset=org_cols)

# %% [markdown]
# # Final data

# %%
# pick necessary column for AIML
ticket_base = (
    df
    .select("ticket_id", "latitude", "longitude", "completion_time_hours")
    .dropDuplicates(["ticket_id"])
)

# org and type onehot
features = (
    ticket_base
    .join(org_wide, on="ticket_id", how="left")
    .join(type_wide, on="ticket_id", how="left")
)

# %%
# this data is for training AI
features_ml = features.drop("ticket_id")
viz_data = df

# %% [markdown]
# # split, examine, and export

# %%
viz_data.printSchema()
# Out:
# root
#  |-- ticket_id: string (nullable = true)
#  |-- organization: string (nullable = true)
#  |-- comment: string (nullable = true)
#  |-- photo: string (nullable = true)
#  |-- photo_after: string (nullable = true)
#  |-- coords: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- subdistrict: string (nullable = true)
#  |-- district: string (nullable = true)
#  |-- province: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- state: string (nullable = true)
#  |-- star: integer (nullable = true)
#  |-- count_reopen: integer (nullable = true)
#  |-- last_activity: timestamp (nullable = true)
#  |-- completion_time_hours: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- type_array: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- organization_distance: double (nullable = true)
#  |-- organization_latitude: double (nullable = true)
#  |-- organization_longitude: double (nullable = true)

# %%
print(len(features_ml.columns))
print(features_ml.columns)
# Out:
# 1609
# ['latitude', 'longitude', 'completion_time_hours', 'dist_1111_ศูนย์รับเรื่องราวร้องทุกข์ของรัฐบาล', 'dist_BTS', 'dist_Bangkok_Smart_Lighting', 'dist_Bangkok_Smart_Lighting__สำนักการโยธา_กทม__', 'dist_CAT_TELECOM__Official_', 'dist_CU_iHouse___CU_Terrace', 'dist_Chula_TUN_JAI_สำนักงานจัดการทรัพย์สิน', 'dist_Chula_TUN_JAI_สำนักบริหารระบบกายภาพ', 'dist_Komgrip', 'dist_MEA', 'dist_MEA_บางขุนเทียน_บำรุงรักษาเสาสาย', 'dist_MEA_บางขุนเทียน_หม้อแปลงฯ', 'dist_MEA_บางขุนเทียน_แก้ไฟฟ้าขัดข้อง', 'dist_MEA_บางขุนเทียน_ไฟฟ้าสาธารณะ', 'dist_MRTA', 'dist_NECTEC', 'dist_NT_ฝ่ายธุรกิจบริการดิจิทัล_ส่วนพันธมิตรบริการดิจิทัล', 'dist_PTT_HO', 'dist_SCGC', 'dist_TOT_smartcity', 'dist_The_line_Jatujak_Mochit__นิติ_', 'dist__ติดตามคำขออนุญาต__ทีมงานผู้ว่าราชการกรุงเทพมหานคร', 'dist_iACO_Bangkokเครือข่ายปปช_ภาคประชาสังคม', 'dist_กกจ_1_ฝกจ_1', 'dist_กกจ_2_ฝกจ_1', 'dist_กกจ_3_ฝกจ_1', 'dist_กกจ_4_ฝกจ_1', 'dist_กกต', 'dist_กทม', 'dist_กผ3_สวจ__สจส__กทม_', 'dist_กฟน_', 'dist_กรมการขนส่งทางบก', 'dist_กรมการขนส่งทางราง', 'dist_กรมการค้าภายใน', 'dist_กรมการปกครอง', 'dist_กรมกิจการผู้สูงอายุ', 'dist_กรมควบคุมมลพิษ', 'dist_กรมชลประทาน', 'dist_กรมทาง', 'dist_กรมทางหลวง', 'dist_กรมทางหลวงชนบท_กระทรวงคมนาคม', 'dist_กรมธนารักษ์___The_Treasury_Department', 'dist_กรมป้องกันและบรรเทาสาธารณภัย', 'dist_กรมสรรพสามิต', 'dist_กรมเจ้าท่า__Marine_Department_', 'dist_กระทรวงการคลัง', 'dist_กระทรวงการต่างประเทศ', 'dist_กระทรวงการท่องเที่ยวและกีฬา', 'dist_กระทรวงการพัฒนาสังคม', 'dist_กระทรวงการอุดมศึกษา_วิทยาศาสตร์_วิจัยและนวัตกรรม', 'dist_กระทรวงคมนาคม', 'dist_กระทรวงดิจิทัลเพื่อเศรษฐกิจและสังคม', 'dist_กระทรวงทรัพยากรธรรมชาติและสิ่งแวดล้อม', 'dist_กระทรวงพลังงาน', 'dist_กระทรวงพัฒนาสังคมและความมั่นคงของมนุษย์', 'dist_กระทรวงพาณิชย์', 'dist_กระทรวงมหาดไทย', 'dist_กระทรวงยุติธรรม', 'dist_กระทรวงวัฒนธรรม', 'dist_กระทรวงศึกษาธิการ', 'dist_กระทรวงสาธารณสุข', 'dist_กระทรวงอุตสาหกรรม', 'dist_กระทรวงเกษตรและสหกรณ์', 'dist_กระทรวงแรงงาน', 'dist_กรุงเทพธนาคม', 'dist_กรุงเทพโปร่งใส', 'dist_กลถ่มงานปลูกและบำรุงรักษาต้นไม้_ฝ่ายรักษาความสะอาดและสวนสาธทรณะ_สำนักงานเขตสาทร', 'dist_กลุ่มกฎหมายการศึกษา_สำนักนิติการ_สำนักงานปลัดกระทรวงศึกษาธิการ', 'dist_กลุ่มงานขยายพันธุ์ไม้_สสณ__สสล_', 'dist_กลุ่มงานควบคุมการก่อสร้าง_1_กองควบคุมการก่อสร้าง__กคส_สนย__', 'dist_กลุ่มงานควบคุมการก่อสร้าง_2_กองควบคุมการก่อสร้าง__กคส_สนย__', 'dist_กลุ่มงานควบคุมการก่อสร้าง_3_กองควบคุมการก่อสร้าง__กคส_สนย__', 'dist_กลุ่มงานควบคุมการก่อสร้าง_4_กองควบคุมการก่อสร้าง__กคส_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_1_ส่วนควบคุมอาคาร_1_สำนักงานควบคุมอาคาร__สคอ_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_1_ส่วนควบคุมอาคาร_2_สำนักงานควบคุมอาคาร__สคอ_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_2_ส่วนควบคุมอาคาร_1_สำนักงานควบคุมอาคาร__สคอ_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_2_ส่วนควบคุมอาคาร_2_สำนักงานควบคุมอาคาร__สคอ_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_ฝ่ายโยธา_เขตภาษีเจริญ', 'dist_กลุ่มงานควบคุมอาคาร_ฝ่ายโยธา_เขตห้วยขวาง', 'dist_กลุ่มงานจัดการระบบราง_สขร_สขส_สจส__กทม_', 'dist_กลุ่มงานตกแต่ง_สำนักงานออกแบบ__สอบ_สนย__', 'dist_กลุ่มงานตรวจสอบระบบสาธารณูปโภค_กองแผนงานและประสานสาธารณูปโภค__กผภ_สนย__', 'dist_กลุ่มงานบริหารทรัพย์สิน_สขส_สจส__กทม_', 'dist_กลุ่มงานบูรณะสะพานและทางโครงสร้างพิเศษ_สำนักงานวิศวกรรมทาง__สวก_สนย__', 'dist_กลุ่มงานพัฒนาระบบโครงข่าย_สบน_สขส_สจส__กทม_', 'dist_กลุ่มงานระบบขนส่งทางบกและทางน้ำ_สบน_สขส_สจส__กทม_', 'dist_กลุ่มงานระบายน้ำ__ฝ่ายโยธา_เขตบางรัก_', 'dist_กลุ่มงานระบายน้ำ_ฝ่ายโยธา_ห้วยขวาง', 'dist_กลุ่มงานระบายน้ำ_ฝ่ายโยธา_เขตบางเขน', 'dist_กลุ่มงานระบายน้ำ_ฝ่ายโยธา_เขตภาษีเจริญ', 'dist_กลุ่มงานระบายน้ำ_เขตสายไหม', 'dist_กลุ่มงานรักษาความสะอาด_เขตบางเขน', 'dist_กลุ่มงานรักษาที่_ฝ่ายโยธา_เขตบางเขน', 'dist_กลุ่มงานรักษาที่สาธารณะ_ฝ่ายโยธา_ห้วยขวาง', 'dist_กลุ่มงานรักษาที่ฯ_ฝ่ายโยธา_เขตภาษีเจริญ', 'dist_กลุ่มงานวางแผนและออกแบบ_1_สวจ_สจส__กทม_', 'dist_กลุ่มงานวางแผนและออกแบบ_2_สวจ_สจส__กทม_', 'dist_กลุ่มงานวางแผนและออกแบบ_3_สวจ_สจส__กทม_', 'dist_กลุ่มงานวิจัยและพัฒนา_สจฝ__สสล_', 'dist_กลุ่มงานวิศวกรรม_กกฝ__สสล_', 'dist_กลุ่มงานศึกษาและวิเคราะห์ผลกระทบสิ่งแวดล้อม_กจอ__สสล_', 'dist_กลุ่มงานสวนสาธารณะ_เขตบางเขน', 'dist_กลุ่มงานสัญญาณไฟจราจร_ส ...

# %%
features_ml.select("completion_time_hours").describe().show()
quantiles = features_ml.approxQuantile(
    "completion_time_hours",
    probabilities=[0.0, 0.1, 0.25, 0.5, 0.75, 0.9, 1.0],
    relativeError=0.01
)

print("Quantiles:")
print("min = ", quantiles[0])
print("10% =", quantiles[1])
print("25% =", quantiles[2])
print("50% =", quantiles[3])
print("75% =", quantiles[4])
print("90% =", quantiles[5])
print("max =",  quantiles[6])

features_ml.select("completion_time_hours").rdd.flatMap(lambda x: x).histogram(10)
# Out:
# +-------+---------------------+
# |summary|completion_time_hours|
# +-------+---------------------+
# |  count|               544599|
# |   mean|    1612.202140065448|
# | stddev|    3121.189844911014|
# |    min| 0.006111111111111111|
# |    max|    25765.44638888889|
# +-------+---------------------+
#
# Quantiles:
# min =  0.006111111111111111
# 10% = 15.692777777777778
# 25% = 43.93277777777778
# 50% = 186.6197222222222
# 75% = 1396.5925
# 90% = 5327.8469444444445
# max = 25765.44638888889
# ([0.006111111111111111,
#   2576.5501388888893,
#   5153.094166666667,
#   7729.638194444445,
#   10306.182222222224,
#   12882.726250000002,
#   15459.27027777778,
#   18035.814305555556,
#   20612.358333333334,
#   23188.90236111111,
#   25765.44638888889],
#  [442170, 42212, 25486, 17128, 8410, 4673, 2733, 1060, 723, 4])

# %% [markdown]
# <h1> stratification </h1>

# %%
from pyspark.sql import Window

# 1. Create 10 bins based on completion_time_hours (approx quantiles)
w = Window.orderBy("completion_time_hours")

features_binned = (
    features_ml
    .withColumn("time_bin", F.ntile(10).over(w))     # 10 bins: 1..10
    .withColumn("row_id", F.monotonically_increasing_id())  # unique ID
    .cache()
)


# 2. For each bin, we want 20% of rows in test set
fractions = (
    features_binned
    .select("time_bin")
    .distinct()
    .withColumn("fraction", F.lit(0.2))    # 20% per bin for test set
    .rdd
    .map(lambda row: (row["time_bin"], row["fraction"]))
    .collectAsMap()
)

print(fractions)  # just to inspect, should be {1: 0.2, 2: 0.2, ..., 10: 0.2}


# 3. Sample test_data stratified by time_bin
test_data = features_binned.stat.sampleBy(
    "time_bin",
    fractions,
    seed=1234
)

# 4) Get only the IDs for test_data
test_ids = test_data.select("row_id")

# 5) Train = all rows whose row_id is NOT in test_ids
train_data = features_binned.join(test_ids, on="row_id", how="left_anti")

train_data = train_data.drop("time_bin", "row_id")
test_data  = test_data.drop("time_bin", "row_id")
# Out:
# {1: 0.2, 2: 0.2, 3: 0.2, 4: 0.2, 5: 0.2, 6: 0.2, 7: 0.2, 8: 0.2, 9: 0.2, 10: 0.2}

# %%
test_data.select("completion_time_hours").describe().show()
quantiles = test_data.approxQuantile(
    "completion_time_hours",
    probabilities=[0.0, 0.1, 0.25, 0.5, 0.75, 0.9, 1.0],
    relativeError=0.01
)

print("Quantiles:")
print("min = ", quantiles[0])
print("10% =", quantiles[1])
print("25% =", quantiles[2])
print("50% =", quantiles[3])
print("75% =", quantiles[4])
print("90% =", quantiles[5])
print("max =",  quantiles[6])

test_data.select("completion_time_hours").rdd.flatMap(lambda x: x).histogram(10)
# Out:
# +-------+---------------------+
# |summary|completion_time_hours|
# +-------+---------------------+
# |  count|               109113|
# |   mean|    1606.712115923137|
# | stddev|   3120.1955987584147|
# |    min| 0.015277777777777777|
# |    max|           23303.6875|
# +-------+---------------------+
# Quantiles:
# min =  0.015277777777777777
# 10% = 16.01638888888889
# 25% = 44.091944444444444
# 50% = 185.74138888888888
# 75% = 1324.9352777777779
# 90% = 5205.285
# max = 23303.6875
# ([0.015277777777777777,
#   2330.3824999999997,
#   4660.749722222222,
#   6991.116944444444,
#   9321.484166666667,
#   11651.85138888889,
#   13982.218611111111,
#   16312.585833333333,
#   18642.953055555554,
#   20973.320277777777,
#   23303.6875],
#  [87468, 8198, 5467, 3230, 2273, 1098, 710, 361, 191, 117])

# %%
train_data.select("completion_time_hours").describe().show()
quantiles = train_data.approxQuantile(
    "completion_time_hours",
    probabilities=[0.0, 0.1, 0.25, 0.5, 0.75, 0.9, 1.0],
    relativeError=0.01
)

print("Quantiles:")
print("min = ", quantiles[0])
print("10% =", quantiles[1])
print("25% =", quantiles[2])
print("50% =", quantiles[3])
print("75% =", quantiles[4])
print("90% =", quantiles[5])
print("max =",  quantiles[6])

train_data.select("completion_time_hours").rdd.flatMap(lambda x: x).histogram(10)
# Out:
# +-------+---------------------+
# |summary|completion_time_hours|
# +-------+---------------------+
# |  count|               435486|
# |   mean|   1613.5776906095211|
# | stddev|    3121.440977020044|
# |    min| 0.006111111111111111|
# |    max|    25765.44638888889|
# +-------+---------------------+
#
# Quantiles:
# min =  0.006111111111111111
# 10% = 16.90222222222222
# 25% = 43.628055555555555
# 50% = 186.99722222222223
# 75% = 1351.1236111111111
# 90% = 5228.1175
# max = 25765.44638888889
# ([0.006111111111111111,
#   2576.5501388888893,
#   5153.094166666667,
#   7729.638194444445,
#   10306.182222222224,
#   12882.726250000002,
#   15459.27027777778,
#   18035.814305555556,
#   20612.358333333334,
#   23188.90236111111,
#   25765.44638888889],
#  [353520, 33790, 20424, 13654, 6745, 3742, 2195, 841, 572, 3])

# %%
bins, counts = (
    test_data
        .select("completion_time_hours")
        .rdd.flatMap(lambda x: x)
        .histogram(10)
)

plt.figure(figsize=(6,4))

# use bins[:-1] as bar start positions, np.diff(bins) as bar widths
plt.bar(bins[:-1], counts, width=np.diff(bins), align="edge")

plt.xlabel("completion_time_hours")
plt.ylabel("count")
plt.title("Histogram of completion_time_hours")

plt.tight_layout()
plt.show()

# %%
bins, counts = (
    train_data
        .select("completion_time_hours")
        .rdd.flatMap(lambda x: x)
        .histogram(10)
)

plt.figure(figsize=(6,4))

# use bins[:-1] as bar start positions, np.diff(bins) as bar widths
plt.bar(bins[:-1], counts, width=np.diff(bins), align="edge")

plt.xlabel("completion_time_hours")
plt.ylabel("count")
plt.title("Histogram of completion_time_hours")

plt.tight_layout()
plt.show()

# %%
bins, counts = (
    features_ml
        .select("completion_time_hours")
        .rdd.flatMap(lambda x: x)
        .histogram(10)
)

plt.figure(figsize=(6,4))

# use bins[:-1] as bar start positions, np.diff(bins) as bar widths
plt.bar(bins[:-1], counts, width=np.diff(bins), align="edge")

plt.xlabel("completion_time_hours")
plt.ylabel("count")
plt.title("Histogram of completion_time_hours")

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>export</h1>

# %%
path_to_your_folder = "C:/Users/Noon/Documents/DSDE/projectTraffy/1"
test_path = f"{path_to_your_folder}/test_data"
train_path = f"{path_to_your_folder}/train_data"
viz_path = f"{path_to_your_folder}/cleaned_Viz_data"
data_ml_path = f"{path_to_your_folder}/cleaned_ml_data"

# %%
n_partitions = 10

# %%
train_data.repartition(n_partitions).write.mode("overwrite").option("header", "true").csv(train_path)

# %%
test_data.repartition(n_partitions).write.mode("overwrite").option("header", "true").csv(test_path)

# %%
viz_data.coalesce(1).write.mode("overwrite").json(viz_path)

# %%
features_ml.repartition(n_partitions).write.mode("overwrite").option("header", "true").csv(data_ml_path)
