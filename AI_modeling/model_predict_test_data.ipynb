# %%
import pandas as pd
from glob import glob

# %%
folder = "C:/Users/Noon/Documents/DSDE/projectTraffy/1/test_data"

# find only data files (ignore .crc)
files = glob(f"{folder}/part-*.csv")

dfs = [pd.read_csv(f) for f in files]

test_data = pd.concat(dfs, ignore_index=True)

# %%
org_dist_cols = [col for col in test_data.columns if col.startswith("dist")]
print(len(org_dist_cols))
print(org_dist_cols)
# Out:
# 1529
# ['dist_1111_ศูนย์รับเรื่องราวร้องทุกข์ของรัฐบาล', 'dist_BTS', 'dist_Bangkok_Smart_Lighting', 'dist_Bangkok_Smart_Lighting__สำนักการโยธา_กทม__', 'dist_CAT_TELECOM__Official_', 'dist_CU_iHouse___CU_Terrace', 'dist_Chula_TUN_JAI_สำนักงานจัดการทรัพย์สิน', 'dist_Chula_TUN_JAI_สำนักบริหารระบบกายภาพ', 'dist_Komgrip', 'dist_MEA', 'dist_MEA_บางขุนเทียน_บำรุงรักษาเสาสาย', 'dist_MEA_บางขุนเทียน_หม้อแปลงฯ', 'dist_MEA_บางขุนเทียน_แก้ไฟฟ้าขัดข้อง', 'dist_MEA_บางขุนเทียน_ไฟฟ้าสาธารณะ', 'dist_MRTA', 'dist_NECTEC', 'dist_NT_ฝ่ายธุรกิจบริการดิจิทัล_ส่วนพันธมิตรบริการดิจิทัล', 'dist_PTT_HO', 'dist_SCGC', 'dist_TOT_smartcity', 'dist_The_line_Jatujak_Mochit__นิติ_', 'dist__ติดตามคำขออนุญาต__ทีมงานผู้ว่าราชการกรุงเทพมหานคร', 'dist_iACO_Bangkokเครือข่ายปปช_ภาคประชาสังคม', 'dist_กกจ_1_ฝกจ_1', 'dist_กกจ_2_ฝกจ_1', 'dist_กกจ_3_ฝกจ_1', 'dist_กกจ_4_ฝกจ_1', 'dist_กกต', 'dist_กทม', 'dist_กผ3_สวจ__สจส__กทม_', 'dist_กฟน_', 'dist_กรมการขนส่งทางบก', 'dist_กรมการขนส่งทางราง', 'dist_กรมการค้าภายใน', 'dist_กรมการปกครอง', 'dist_กรมกิจการผู้สูงอายุ', 'dist_กรมควบคุมมลพิษ', 'dist_กรมชลประทาน', 'dist_กรมทาง', 'dist_กรมทางหลวง', 'dist_กรมทางหลวงชนบท_กระทรวงคมนาคม', 'dist_กรมธนารักษ์___The_Treasury_Department', 'dist_กรมป้องกันและบรรเทาสาธารณภัย', 'dist_กรมสรรพสามิต', 'dist_กรมเจ้าท่า__Marine_Department_', 'dist_กระทรวงการคลัง', 'dist_กระทรวงการต่างประเทศ', 'dist_กระทรวงการท่องเที่ยวและกีฬา', 'dist_กระทรวงการพัฒนาสังคม', 'dist_กระทรวงการอุดมศึกษา_วิทยาศาสตร์_วิจัยและนวัตกรรม', 'dist_กระทรวงคมนาคม', 'dist_กระทรวงดิจิทัลเพื่อเศรษฐกิจและสังคม', 'dist_กระทรวงทรัพยากรธรรมชาติและสิ่งแวดล้อม', 'dist_กระทรวงพลังงาน', 'dist_กระทรวงพัฒนาสังคมและความมั่นคงของมนุษย์', 'dist_กระทรวงพาณิชย์', 'dist_กระทรวงมหาดไทย', 'dist_กระทรวงยุติธรรม', 'dist_กระทรวงวัฒนธรรม', 'dist_กระทรวงศึกษาธิการ', 'dist_กระทรวงสาธารณสุข', 'dist_กระทรวงอุตสาหกรรม', 'dist_กระทรวงเกษตรและสหกรณ์', 'dist_กระทรวงแรงงาน', 'dist_กรุงเทพธนาคม', 'dist_กรุงเทพโปร่งใส', 'dist_กลถ่มงานปลูกและบำรุงรักษาต้นไม้_ฝ่ายรักษาความสะอาดและสวนสาธทรณะ_สำนักงานเขตสาทร', 'dist_กลุ่มกฎหมายการศึกษา_สำนักนิติการ_สำนักงานปลัดกระทรวงศึกษาธิการ', 'dist_กลุ่มงานขยายพันธุ์ไม้_สสณ__สสล_', 'dist_กลุ่มงานควบคุมการก่อสร้าง_1_กองควบคุมการก่อสร้าง__กคส_สนย__', 'dist_กลุ่มงานควบคุมการก่อสร้าง_2_กองควบคุมการก่อสร้าง__กคส_สนย__', 'dist_กลุ่มงานควบคุมการก่อสร้าง_3_กองควบคุมการก่อสร้าง__กคส_สนย__', 'dist_กลุ่มงานควบคุมการก่อสร้าง_4_กองควบคุมการก่อสร้าง__กคส_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_1_ส่วนควบคุมอาคาร_1_สำนักงานควบคุมอาคาร__สคอ_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_1_ส่วนควบคุมอาคาร_2_สำนักงานควบคุมอาคาร__สคอ_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_2_ส่วนควบคุมอาคาร_1_สำนักงานควบคุมอาคาร__สคอ_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_2_ส่วนควบคุมอาคาร_2_สำนักงานควบคุมอาคาร__สคอ_สนย__', 'dist_กลุ่มงานควบคุมอาคาร_ฝ่ายโยธา_เขตภาษีเจริญ', 'dist_กลุ่มงานควบคุมอาคาร_ฝ่ายโยธา_เขตห้วยขวาง', 'dist_กลุ่มงานจัดการระบบราง_สขร_สขส_สจส__กทม_', 'dist_กลุ่มงานตกแต่ง_สำนักงานออกแบบ__สอบ_สนย__', 'dist_กลุ่มงานตรวจสอบระบบสาธารณูปโภค_กองแผนงานและประสานสาธารณูปโภค__กผภ_สนย__', 'dist_กลุ่มงานบริหารทรัพย์สิน_สขส_สจส__กทม_', 'dist_กลุ่มงานบูรณะสะพานและทางโครงสร้างพิเศษ_สำนักงานวิศวกรรมทาง__สวก_สนย__', 'dist_กลุ่มงานพัฒนาระบบโครงข่าย_สบน_สขส_สจส__กทม_', 'dist_กลุ่มงานระบบขนส่งทางบกและทางน้ำ_สบน_สขส_สจส__กทม_', 'dist_กลุ่มงานระบายน้ำ__ฝ่ายโยธา_เขตบางรัก_', 'dist_กลุ่มงานระบายน้ำ_ฝ่ายโยธา_ห้วยขวาง', 'dist_กลุ่มงานระบายน้ำ_ฝ่ายโยธา_เขตบางเขน', 'dist_กลุ่มงานระบายน้ำ_ฝ่ายโยธา_เขตภาษีเจริญ', 'dist_กลุ่มงานระบายน้ำ_เขตสายไหม', 'dist_กลุ่มงานรักษาความสะอาด_เขตบางเขน', 'dist_กลุ่มงานรักษาที่_ฝ่ายโยธา_เขตบางเขน', 'dist_กลุ่มงานรักษาที่สาธารณะ_ฝ่ายโยธา_ห้วยขวาง', 'dist_กลุ่มงานรักษาที่ฯ_ฝ่ายโยธา_เขตภาษีเจริญ', 'dist_กลุ่มงานวางแผนและออกแบบ_1_สวจ_สจส__กทม_', 'dist_กลุ่มงานวางแผนและออกแบบ_2_สวจ_สจส__กทม_', 'dist_กลุ่มงานวางแผนและออกแบบ_3_สวจ_สจส__กทม_', 'dist_กลุ่มงานวิจัยและพัฒนา_สจฝ__สสล_', 'dist_กลุ่มงานวิศวกรรม_กกฝ__สสล_', 'dist_กลุ่มงานศึกษาและวิเคราะห์ผลกระทบสิ่งแวดล้อม_กจอ__สสล_', 'dist_กลุ่มงานสวนสาธารณะ_เขตบางเขน', 'dist_กลุ่มงานสัญญาณไฟจราจร_สวจ_สจส__กทม_', 'dist_กลุ่มงานสารบรรณกลางและบริหารเ ...

# %%
def add_relevant_cols(df, org_dist_cols):
    relevant = (df[org_dist_cols] > 0).astype(int)
    new_col_names = list()
    for col in org_dist_cols:
        clean = col.replace("dist_", "relevant_")
        new_col_names.append(clean)
    relevant.columns = new_col_names
    return df.join(relevant)

# %%
test_data = add_relevant_cols(test_data, org_dist_cols)
test_data[org_dist_cols] = test_data[org_dist_cols].clip(lower=0)

# %%
from sklearn.cluster import KMeans
import numpy as np
test_data["created_at"] = pd.to_datetime(test_data["timestamp"])

test_data["month"]      = test_data["created_at"].dt.month.astype("int16")
test_data["dayofweek"]  = test_data["created_at"].dt.dayofweek.astype("int8")  # 0=Mon
test_data["hour"]       = test_data["created_at"].dt.hour.astype("int8")
test_data["is_weekend"] = test_data["dayofweek"].isin([5, 6]).astype("int8")
test_data.drop(['timestamp', 'created_at', 'latitude', 'longitude'], axis='columns', inplace=True)

# Fit KMeans on test_data coordinates
coords_train = test_data[["latitude", "longitude"]].dropna()

kmeans = KMeans(n_clusters=50, random_state=42)
kmeans.fit(coords_train)

# Assign region IDs to train and test
test_data["region"] = kmeans.predict(test_data[["latitude", "longitude"]])
# print(test_data["region"].value_counts().sort_index())

# One-hot encode region
test_data = pd.get_dummies(test_data, columns=["region"], prefix="region")
hours_7 = 7 * 24
test_data["fast_7d"]  = (test_data["completion_time_hours"] <= hours_7).astype(int)

# 3) Train/val split (stratify to keep class balance)
feature_cols = [col for col in test_data.columns if col not in ["completion_time_hours", "log_completion_hours", "time_bucket", "fast_7d"]]

X_test = test_data[feature_cols]
y_test = test_data["fast_7d"]
# Out:
# C:\Users\Noon\AppData\Local\Temp\ipykernel_14076\2107657166.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data["created_at"] = pd.to_datetime(test_data["timestamp"])
# C:\Users\Noon\AppData\Local\Temp\ipykernel_14076\2107657166.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data["month"]      = test_data["created_at"].dt.month.astype("int16")
# C:\Users\Noon\AppData\Local\Temp\ipykernel_14076\2107657166.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data["dayofweek"]  = test_data["created_at"].dt.dayofweek.astype("int8")  # 0=Mon
# C:\Users\Noon\AppData\Local\Temp\ipykernel_14076\2107657166.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data["hour"]       = test_data["created_at"].dt.hour.astype("int8")
# C:\Users\Noon\AppData\Local\Temp\ipykernel_14076\2107657166.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data["is_weekend"] = test_data["dayofweek"].isin([5, 6]).astype("int8")
# C:\Users\Noon\AppData\Local\Temp\ipykernel_14076\2107657166.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data["region"] = kmeans.predict(test_data[["latitude", "longitude"]])

# %%
import joblib
import pandas as pd
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    confusion_matrix,
    roc_auc_score,
)

# Load
package = joblib.load("fast_7day_model.joblib")
clf_bin = package["model"]

y_proba = clf_bin.predict_proba(X_test)[:, 1]
y_pred  = clf_bin.predict(X_test)

# 6) Metrics
acc = accuracy_score(y_test, y_pred)
prec, rec, f1, _ = precision_recall_fscore_support(
    y_test, y_pred, average="binary", zero_division=0
)

try:
    auc = roc_auc_score(y_test, y_proba)
except ValueError:
    auc = None

print("\n=== Binary ≤7 days vs >7 days ===")
print("Accuracy:", acc)
print("Precision (fast<=7d):", prec)
print("Recall (fast<=7d):", rec)
print("F1 (fast<=7d):", f1)
print("ROC-AUC:", auc)

print("\nClassification report:")
print(classification_report(
    y_test,
    y_pred,
    target_names=[">7 days", "≤7 days"],
    zero_division=0
))

print("Confusion matrix (rows=true, cols=pred):")
print(confusion_matrix(y_test, y_pred))

# 7) Simple baseline: always predict majority class
majority_class = y_test.mode()[0]
y_baseline = np.full_like(y_test, majority_class)

acc_base = accuracy_score(y_test, y_baseline)
print("\nBaseline (always predict class", majority_class, ") accuracy:", acc_base)
# Out:
# === Binary ≤7 days vs >7 days ===
# Accuracy: 0.7359269316218218
# Precision (fast<=7d): 0.6994835377663008
# Recall (fast<=7d): 0.7714004522991875
# F1 (fast<=7d): 0.733683854135548
# ROC-AUC: 0.8170167422014905
#
# Classification report:
#               precision    recall  f1-score   support
#
#      >7 days       0.78      0.70      0.74     53519
#      ≤7 days       0.70      0.77      0.73     47756
#
#     accuracy                           0.74    101275
#    macro avg       0.74      0.74      0.74    101275
# weighted avg       0.74      0.74      0.74    101275
#
# Confusion matrix (rows=true, cols=pred):
# [[37692 15827]
#  [10917 36839]]
#
# Baseline (always predict class 0 ) accuracy: 0.5284522340162923
